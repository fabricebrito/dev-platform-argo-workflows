# %%
import requests
import time
import os
import requests
import json

# %%
# Configuration
NAMESPACE = "ns1"
ARGO_SERVER_URL = f"http://localhost:2746/api/v1"

# this token is generated by the argo server with the following command:
# kubectl get -n ns1 secret argo.service-account-token -o=jsonpath='{.data.token}' | base64 --decode
AUTH_TOKEN = "eyJhbGciOiJSUzI1NiIsImtpZCI6ImNtR2dMYUdaLWk4MS1IbjkyNWs3ejhrMkl3VFdOZWZnRS12QzdfdkwtTGsifQ.....Bxe3oPSK_pjjfanfeSskJ4QMFaVr6joDBbugBuDNS2KYzEFOkcaaUXaGmSXTqIsRPc1VWCrl9hKHrJL2I4mPsIA-AmxLcjh0N2I0Gvj_DRuqWhcAu1ENVT8Gtme5m7iZ6dyjS6_M-agfV9QmhADjowmW58gQwMlEVdXnAw_LISwFBUFX2_CNnw5sOFrpADVP7C7ksa8Q0IUHJebTpMTeDmTaJv-pBd2c7nbdLAoDnzKCD27LUcmGZJruieOJccLXztsHQfD8v3lz7KIBH2264cyHUH74AQIlR1WDWMDEu6xZCdHhmQ2fRT12GlyXZB7DsYhuw575qqtpdRs6Y2qa2w"

# %% [markdown]
# ## List available "Processes"

# %%
# Headers for API request
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
}

print(f"API endpoint: GET {ARGO_SERVER_URL}/workflow-templates/{NAMESPACE}")

response = requests.get(f"{ARGO_SERVER_URL}/workflow-templates/{NAMESPACE}", headers=headers)

print(response.status_code)
# Out:
# API endpoint: GET http://localhost:2746/api/v1/workflow-templates/ns1
# 200

# %% [markdown]
# Get information about the available "Processes"

# %%
response.json().get("items", {})

for item in response.json().get("items", {}):
    print(item.get("metadata", {}).get("name", {}))
    print(item.get("metadata", {}).get("annotations", {}).get("workflows.argoproj.io/description", {}))
    print(item.get("metadata", {}).get("annotations", {}).get("eoap.ogc.org/version", "N/A"))
    print("---")
# Out:
# argo-cwl-runner
# This workflow template is a CWL runner for Argo Workflows.
#
# N/A
# ---
# water-bodies-detection
# This workflow template detects water bodies.
#
# 1.0.0
# ---

# %% [markdown]
# ## Describe "Process"

# %%
id = "water-bodies-detection"

# Headers for API request
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
}

print(f"API endpoint: GET {ARGO_SERVER_URL}/workflow-templates/{NAMESPACE}/{id}")

response = requests.get(f"{ARGO_SERVER_URL}/workflow-templates/{NAMESPACE}/{id}", headers=headers)

print(response.status_code)
# Out:
# API endpoint: GET http://localhost:2746/api/v1/workflow-templates/ns1/water-bodies-detection
# 200

# %% [markdown]
# "Processes" have an entrypoint:

# %%
entry_point = response.json().get("spec", {}).get("entrypoint", None)

entry_point
# Out:
# 'main'

# %% [markdown]
# Get the "Process" entry point template:

# %%
[template for template in response.json().get("spec", {}).get("templates", {}) if template["name"] == entry_point]
# Out:
# [{'name': 'main',
#   'inputs': {'parameters': [{'name': 'items',
#      'description': 'JSON array of STAC items to process'},
#     {'name': 'aoi',
#      'description': "Area of interest expressed as a bounding box 'minx,miny,maxx,maxy'"},
#     {'name': 'epsg',
#      'default': 'EPSG:4326',
#      'description': 'EPSG code of the bounding box coordinates'}]},
#   'outputs': {'parameters': [{'name': 'results',
#      'valueFrom': {'expression': "steps['argo-cwl'].outputs.parameters['results']"},
#      'description': 'JSON array results produced by the CWL execution'},
#     {'name': 'log',
#      'valueFrom': {'expression': "steps['argo-cwl'].outputs.parameters['log']"},
#      'description': 'Log produced by the CWL execution'},
#     {'name': 'usage-report',
#      'valueFrom': {'expression': "steps['argo-cwl'].outputs.parameters['usage-report']"},
#      'description': 'Usage report produced by the CWL execution'},
#     {'name': 'stac-catalog',
#      'valueFrom': {'expression': "steps['argo-cwl'].outputs.parameters['stac-catalog']"},
#      'description': 'STAC catalog with the detected water bodies and published on S3'}],
#    'artifacts': [{'name': 'tool-logs',
#      'fromExpression': "steps['argo-cwl'].outputs.artifacts['tool-logs']"},
#     {'name': 'calrissian-output',
#      'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-output']"},
#     {'name': 'calrissian-stderr',
#      'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-stderr']"},
#     {'name': 'calrissian-report',
#      'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-report']"}]},
#   'metadata': {},
#   'steps': [[{'name': 'prepare',
#      'template': 'prepare',
#      'arguments': {'parameters': [{'name': 'items',
#         'value': '{{inputs.parameters.items}}'},
#        {'name': 'aoi', 'value': '{{inputs.parameters.aoi}}'},
#        {'name': 'epsg', 'value': '{{inputs.parameters.epsg}}'}]}}],
#    [{'name': 'validate-inputs',
#      'template': 'validate-inputs',
#      'arguments': {'parameters': [{'name': 'inputs',
#         'value': '{{steps.prepare.outputs.parameters.inputs}}'}]}}],
#    [{'name': 'argo-cwl',
#      'arguments': {'parameters': [{'name': 'max_ram', 'value': '4G'},
#        {'name': 'max_cores', 'value': '4'},
#        {'name': 'parameters',
#         'value': '{{steps.prepare.outputs.parameters.inputs}}'},
#        {'name': 'cwl',
#         'value': '{{steps.prepare.outputs.parameters.workflow}}'}]},
#      'templateRef': {'name': 'argo-cwl-runner',
#       'template': 'calrissian-runner'}}]]}]

# %%
main = [template for template in response.json().get("spec", {}).get("templates", {}) if template["name"] == entry_point][0]

# %% [markdown]
# Get the "Process" inputs

# %%
for input_parameter in main["inputs"]["parameters"]:
    print(f"id: {input_parameter['name']}")
    print(f"description: {input_parameter.get('description', 'N/A')}")
    print(f"default value: {input_parameter.get('default', 'N/A')}")
    print("---")
# Out:
# id: items
# description: JSON array of STAC items to process
# default value: N/A
# ---
# id: aoi
# description: Area of interest expressed as a bounding box 'minx,miny,maxx,maxy'
# default value: N/A
# ---
# id: epsg
# description: EPSG code of the bounding box coordinates
# default value: EPSG:4326
# ---

# %% [markdown]
# Get the "Process" outputs

# %%
for output_parameter in main["outputs"]["parameters"]:
    print(f"id: {output_parameter['name']}")
    print(f"description: {output_parameter.get('description', 'N/A')}")
    print("---")
# Out:
# id: results
# description: JSON array results produced by the CWL execution
# ---
# id: log
# description: Log produced by the CWL execution
# ---
# id: usage-report
# description: Usage report produced by the CWL execution
# ---
# id: stac-catalog
# description: STAC catalog with the detected water bodies and published on S3
# ---

# %% [markdown]
# Get the "Process" artifacts

# %%
for artifact in main["outputs"]["artifacts"]:
    print(artifact)
    print(f"id: {artifact['name']}")
    print("---")
# Out:
# {'name': 'tool-logs', 'fromExpression': "steps['argo-cwl'].outputs.artifacts['tool-logs']"}
# id: tool-logs
# ---
# {'name': 'calrissian-output', 'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-output']"}
# id: calrissian-output
# ---
# {'name': 'calrissian-stderr', 'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-stderr']"}
# id: calrissian-stderr
# ---
# {'name': 'calrissian-report', 'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-report']"}
# id: calrissian-report
# ---

# %% [markdown]
# ## "Process" execution submission

# %% [markdown]
# Create the payload

# %%
parameters = [{"items":["https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"]},
      {"aoi": "-121.399,39.834,-120.74,40.472"},
      {"epsg": "EPSG:4326"}]

# %% [markdown]
# Convert the parameters to a list of strings

# %%
payload_parameters = []
for param in parameters:
    for key, value in param.items():
        if isinstance(value, list):
            # Join the list items with double quotes and format with brackets
            items_str = '[' + ','.join(f'"{item}"' for item in value) + ']'
            payload_parameters.append(f"{key}={items_str}")
        else:
            payload_parameters.append(f"{key}={value}")

payload_parameters
# Out:
# ['items=["https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"]',
#  'aoi=-121.399,39.834,-120.74,40.472',
#  'epsg=EPSG:4326']

# %% [markdown]
# Execution payload:

# %%
# Payload with parameters
payload = {
  "resourceKind": "WorkflowTemplate",
  "resourceName": id,
  "submitOptions": {
    "parameters": payload_parameters
  }
}

payload
# Out:
# {'resourceKind': 'WorkflowTemplate',
#  'resourceName': 'water-bodies-detection',
#  'submitOptions': {'parameters': ['items=["https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"]',
#    'aoi=-121.399,39.834,-120.74,40.472',
#    'epsg=EPSG:4326']}}

# %%
# Headers for API request
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
    "Content-Type": "application/json"
}

print(f"API endpoint: POST {ARGO_SERVER_URL}/workflows/{NAMESPACE}/submit")


# Submit the workflow and handle the response
response = requests.post(
    f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}/submit",
    headers=headers,
    json=payload,
    verify=False  # Use verify=True if you have valid SSL certificates
)

response.status_code
# Out:
# API endpoint: POST http://localhost:2746/api/v1/workflows/ns1/submit
# 200

# %%
if response.status_code == 200 or response.status_code == 201:
    # Decode JSON response
    workflow_info = response.json()
    workflow_name = workflow_info["metadata"]["name"]
    print(f"Workflow submitted successfully with name: {workflow_name}")
else:
    print("Failed to submit workflow:")
    print(response.text)
# Out:
# Workflow submitted successfully with name: water-bodies-detection-j6xk6

# %% [markdown]
# ## List "Jobs"

# %%
print(f"API endpoint: GET {ARGO_SERVER_URL}/workflows/{NAMESPACE}")

response = requests.get(f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}", headers=headers)
# Out:
# API endpoint: GET http://localhost:2746/api/v1/workflows/ns1

# %%
for item in response.json().get("items", {}):
    print(f"name: {item.get('metadata', {}).get('name', {})}")
    print(f"submission date: {item.get('metadata', {}).get('creationTimestamp', {})}")
    print(f"uid: {item.get('metadata', {}).get('uid', {})}")
    print(f"submission date: {item.get('metadata', {}).get('creationTimestamp', {})}")
    print(f"job type: {item.get('spec', {}).get('workflowTemplateRef', {}).get('name', {})}") 
    print(f"status: {item.get('status', {}).get('phase', {})}")  
    print(f"started at: {item.get('status', {}).get('startedAt', {})}") 
    print(f"finished at: {item.get('status', {}).get('finishedAt', {})}")  
    print(f"progress: {item.get('status', {}).get('progress', {})}")      
    print("---")
# Out:
# name: water-bodies-detection-j6xk6
# submission date: 2024-11-07T06:58:52Z
# uid: d0c9e3c4-67e9-4e4e-9479-454a5d31dff0
# submission date: 2024-11-07T06:58:52Z
# job type: water-bodies-detection
# status: Running
# started at: 2024-11-07T06:58:52Z
# finished at: None
# progress: 3/4
# ---
# name: water-bodies-detection-8dfrj
# submission date: 2024-11-07T06:17:59Z
# uid: 9ba225ad-0054-4269-928f-d5c14688f0f4
# submission date: 2024-11-07T06:17:59Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T06:17:59Z
# finished at: 2024-11-07T06:19:51Z
# progress: 6/6
# ---
# name: water-bodies-detection-bzfrz
# submission date: 2024-11-06T16:02:03Z
# uid: 8739eaf7-4883-4033-84cb-cab504f26b7f
# submission date: 2024-11-06T16:02:03Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T16:02:03Z
# finished at: 2024-11-06T16:05:20Z
# progress: 6/6
# ---
# name: water-bodies-detection-kwjqw
# submission date: 2024-11-06T15:58:21Z
# uid: 756a2e99-5930-451b-a846-0da6734931be
# submission date: 2024-11-06T15:58:21Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:58:21Z
# finished at: 2024-11-06T16:01:08Z
# progress: 6/6
# ---
# name: water-bodies-detection-52k25
# submission date: 2024-11-06T15:46:18Z
# uid: 923da8ea-60ef-48ef-87d5-6aae9e26accf
# submission date: 2024-11-06T15:46:18Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:53:30Z
# finished at: 2024-11-06T15:56:36Z
# progress: 6/6
# ---
# name: water-bodies-detection-z8s6d
# submission date: 2024-11-06T15:43:40Z
# uid: 991f791f-b24f-4e6f-b2da-02bb2bbab8c4
# submission date: 2024-11-06T15:43:40Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:48:40Z
# finished at: 2024-11-06T15:53:52Z
# progress: 6/6
# ---
# name: water-bodies-detection-7xrzm
# submission date: 2024-11-06T15:43:48Z
# uid: 83fc33d1-c845-4c9f-b991-7bd66aace2c2
# submission date: 2024-11-06T15:43:48Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:48:42Z
# finished at: 2024-11-06T15:53:48Z
# progress: 6/6
# ---
# name: water-bodies-detection-zn2cc
# submission date: 2024-11-06T15:43:21Z
# uid: 887e00a7-25c9-43a8-9611-468b18442039
# submission date: 2024-11-06T15:43:21Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:48:37Z
# finished at: 2024-11-06T15:53:29Z
# progress: 6/6
# ---
# name: water-bodies-detection-zk6v2
# submission date: 2024-11-06T15:36:34Z
# uid: cfd8b5c4-647a-4bd0-b559-89d3fd9deeb2
# submission date: 2024-11-06T15:36:34Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:36:34Z
# finished at: 2024-11-06T15:48:41Z
# progress: 6/6
# ---
# name: water-bodies-detection-kqbnz
# submission date: 2024-11-06T15:42:02Z
# uid: 0dfcf6b1-76c3-4f49-9f36-0c40dc663e18
# submission date: 2024-11-06T15:42:02Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:42:02Z
# finished at: 2024-11-06T15:48:39Z
# progress: 6/6
# ---
# name: water-bodies-detection-p5bzq
# submission date: 2024-11-06T15:37:30Z
# uid: 0bc2ac3a-2e0c-41a8-8041-63cd93e37e3d
# submission date: 2024-11-06T15:37:30Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:37:30Z
# finished at: 2024-11-06T15:48:36Z
# progress: 6/6
# ---

# %% [markdown]
# The element `status.nodes` provides detailed information about the workflow nodes

# %%
job_name = workflow_info.get("metadata", {}).get("name", {}) 

job_name
# Out:
# 'water-bodies-detection-j6xk6'

# %% [markdown]
# ## "Job" monitoring

# %%
print(f"API endpoint: GET {ARGO_SERVER_URL}/workflows/{NAMESPACE}/{workflow_name}")

# Headers for API request
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
    "Content-Type": "application/json"
}

def get_workflow_status(workflow_name):
    """Fetches the current status of the workflow."""
    response = requests.get(
        f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}/{workflow_name}",
        headers=headers,
        verify=False  # Use verify=True with valid SSL certificates
    )

    if response.status_code == 200:
        workflow_info = response.json()
        status = workflow_info.get("status", {}).get("phase", "Unknown")
        return status, workflow_info
    else:
        print(f"Failed to retrieve workflow status: {response.status_code}")
        return None

# Monitor the workflow status until it reaches a terminal state
while True:
    status, workflow_status = get_workflow_status(job_name)
    
    if status:
        print(f"Workflow Status: {status}")

        # Check if the workflow has completed
        if status in ["Succeeded", "Failed", "Error"]:
            print(f"Workflow has completed with status: {status}")
            break
    else:
        print("Unable to retrieve workflow status. Exiting monitoring.")
        break

    # Wait for 10 seconds before the next check
    time.sleep(10)
# Out:
# API endpoint: GET http://localhost:2746/api/v1/workflows/ns1/water-bodies-detection-j6xk6
# Workflow Status: Succeeded
# Workflow has completed with status: Succeeded

# %%
print(f"name: {workflow_status.get('metadata', {}).get('name', {})}")
print(f"submission date: {workflow_status.get('metadata', {}).get('creationTimestamp', {})}")
print(f"uid: {workflow_status.get('metadata', {}).get('uid', {})}")
print(f"submission date: {workflow_status.get('metadata', {}).get('creationTimestamp', {})}")
print(f"job type: {workflow_status.get('spec', {}).get('workflowTemplateRef', {}).get('name', {})}") 
print(f"status: {workflow_status.get('status', {}).get('phase', {})}")  
print(f"started at: {workflow_status.get('status', {}).get('startedAt', {})}") 
print(f"finished at: {workflow_status.get('status', {}).get('finishedAt', {})}")  
print(f"progress: {workflow_status.get('status', {}).get('progress', {})}")      
print("---")
# Out:
# name: water-bodies-detection-j6xk6
# submission date: 2024-11-07T06:58:52Z
# uid: d0c9e3c4-67e9-4e4e-9479-454a5d31dff0
# submission date: 2024-11-07T06:58:52Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T06:58:52Z
# finished at: 2024-11-07T07:00:44Z
# progress: 6/6
# ---

# %% [markdown]
# ## Get the "job" outputs: parameters and artifacts

# %% [markdown]
# List the "job" outputs parameters

# %%
for output_parameter in workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("parameters"):
    print(f"id: {output_parameter['name']}")
    print(f"description: {output_parameter.get('description', 'N/A')}")
    print(f"value: {output_parameter.get('value', 'N/A')}")
    print("---")
# Out:
# id: results
# description: JSON array results produced by the CWL execution
# value: {
#     "stac_catalog": {
#         "location": "file:///calrissian/results/64geu8b8",
#         "basename": "64geu8b8",
#         "class": "Directory",
#         "listing": [
#             {
#                 "class": "File",
#                 "location": "file:///calrissian/results/64geu8b8/catalog.json",
#                 "basename": "catalog.json",
#                 "checksum": "sha1$f1994683c2e2b8d21aab7f0c0c05b76b850ac21e",
#                 "size": 359,
#                 "path": "/calrissian/results/64geu8b8/catalog.json"
#             },
#             {
#                 "class": "Directory",
#                 "location": "file:///calrissian/results/64geu8b8/S2A_10TFK_20210708_0_L2A",
#                 "basename": "S2A_10TFK_20210708_0_L2A",
#                 "listing": [
#                     {
#                         "class": "File",
#                         "location": "file:///calrissian/results/64geu8b8/S2A_10TFK_20210708_0_L2A/S2A_10TFK_20210708_0_L2A.json",
#                         "basename": "S2A_10TFK_20210708_0_L2A.json",
#                         "checksum": "sha1$800a04fa6e4644dd1306d9335c237b020cd4bf5a",
#                         "size": 4882,
#                         "path": "/calrissian/results/64geu8b8/S2A_10TFK_20210708_0_L2A/S2A_10TFK_20210708_0_L2A.json"
#                     },
#                     {
#                         "class": "File",
#                         "location": "file:///calrissian/results/64geu8b8/S2A_10TFK_20210708_0_L2A/otsu.tif",
#                         "basename": "otsu.tif",
#                         "checksum": "sha1$210598cf619d49eabfdc24414bd445f59668f3bd",
#                         "size": 289288,
#                         "path": "/calrissian/results/64geu8b8/S2A_10TFK_20210708_0_L2A/otsu.tif"
#                     }
#                 ],
#                 "path": "/calrissian/results/64geu8b8/S2A_10TFK_20210708_0_L2A"
#             }
#         ],
#         "path": "/calrissian/results/64geu8b8"
#     }
# }
# ---
# id: log
# description: Log produced by the CWL execution
# value: INFO calrissian 0.16.0 (cwltool 3.1.20231114134824)
# INFO Resolved '/calrissian/cwl.json' to 'file:///calrissian/cwl.json'
# DEBUG Starting ThreadPoolJobExecutor.run_jobs: total_resources=[ram: 4000.0, cores: 4.0, gpus 0], max_workers=None
# DEBUG [workflow ] initialized from file:///calrissian/cwl.json#main
# DEBUG wait_for_completion with 0 futures
# DEBUG [workflow ] inputs {
#     "stac_items": [
#         "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
#     ],
#     "aoi": "-121.399,39.834,-120.74,40.472",
#     "epsg": "EPSG:4326",
#     "bands": [
#         "green",
#         "nir"
#     ]
# }
# INFO [workflow ] starting step node_water_bodies
# INFO [step node_water_bodies] start
# DEBUG [workflow node_water_bodies] initialized from file:///calrissian/cwl.json#detect_water_body
# DEBUG wait_for_completion with 0 futures
# DEBUG [workflow node_water_bodies] inputs {
#     "aoi": "-121.399,39.834,-120.74,40.472",
#     "bands": [
#         "green",
#         "nir"
#     ],
#     "epsg": "EPSG:4326",
#     "item": "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
# }
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_normalized_difference not ready
# INFO [workflow node_water_bodies] starting step node_crop
# INFO [step node_crop] start
# DEBUG [job node_crop] initializing from file:///calrissian/cwl.json#crop as part of step node_crop
# DEBUG [job node_crop] {
#     "aoi": "-121.399,39.834,-120.74,40.472",
#     "band": "green",
#     "epsg": "EPSG:4326",
#     "item": "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
# }
# DEBUG [job node_crop] path mappings is {}
# DEBUG [job node_crop] command line bindings is [
#     {
#         "position": [
#             -1000000,
#             0
#         ],
#         "datum": "python"
#     },
#     {
#         "position": [
#             -1000000,
#             1
#         ],
#         "datum": "-m"
#     },
#     {
#         "position": [
#             -1000000,
#             2
#         ],
#         "datum": "app"
#     },
#     {
#         "prefix": "--aoi",
#         "position": [
#             0,
#             "aoi"
#         ],
#         "datum": "-121.399,39.834,-120.74,40.472"
#     },
#     {
#         "prefix": "--band",
#         "position": [
#             0,
#             "band"
#         ],
#         "datum": "green"
#     },
#     {
#         "prefix": "--epsg",
#         "position": [
#             0,
#             "epsg"
#         ],
#         "datum": "EPSG:4326"
#     },
#     {
#         "prefix": "--input-item",
#         "position": [
#             0,
#             "item"
#         ],
#         "datum": "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
#     }
# ]
# DEBUG wait_for_completion with 0 futures
# INFO [step node_crop] start
# DEBUG [job node_crop_2] initializing from file:///calrissian/cwl.json#crop as part of step node_crop
# DEBUG [job node_crop_2] {
#     "aoi": "-121.399,39.834,-120.74,40.472",
#     "band": "nir",
#     "epsg": "EPSG:4326",
#     "item": "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
# }
# DEBUG [job node_crop_2] path mappings is {}
# DEBUG [job node_crop_2] command line bindings is [
#     {
#         "position": [
#             -1000000,
#             0
#         ],
#         "datum": "python"
#     },
#     {
#         "position": [
#             -1000000,
#             1
#         ],
#         "datum": "-m"
#     },
#     {
#         "position": [
#             -1000000,
#             2
#         ],
#         "datum": "app"
#     },
#     {
#         "prefix": "--aoi",
#         "position": [
#             0,
#             "aoi"
#         ],
#         "datum": "-121.399,39.834,-120.74,40.472"
#     },
#     {
#         "prefix": "--band",
#         "position": [
#             0,
#             "band"
#         ],
#         "datum": "nir"
#     },
#     {
#         "prefix": "--epsg",
#         "position": [
#             0,
#             "epsg"
#         ],
#         "datum": "EPSG:4326"
#     },
#     {
#         "prefix": "--input-item",
#         "position": [
#             0,
#             "item"
#         ],
#         "datum": "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
#     }
# ]
# DEBUG wait_for_completion with 0 futures
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_normalized_difference not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_normalized_difference not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow ] job step file:///calrissian/cwl.json#main/node_stac not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_normalized_difference not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow ] job step file:///calrissian/cwl.json#main/node_stac not ready
# DEBUG allocate [ram: 0, cores: 0, gpus 0] from available [ram: 4000.0, cores: 4.0, gpus 0]
# INFO [workflow ] start
# DEBUG restore [ram: 0, cores: 0, gpus 0] to available [ram: 4000.0, cores: 4.0, gpus 0]
# DEBUG allocate [ram: 0, cores: 0, gpus 0] from available [ram: 4000.0, cores: 4.0, gpus 0]
# DEBUG allocate [ram: 512, cores: 1, gpus 0] from available [ram: 4000.0, cores: 4.0, gpus 0]
# INFO [workflow node_water_bodies] start
# DEBUG restore [ram: 0, cores: 0, gpus 0] to available [ram: 3488.0, cores: 3.0, gpus 0]
# DEBUG allocate [ram: 512, cores: 1, gpus 0] from available [ram: 3488.0, cores: 3.0, gpus 0]
# DEBUG wait_for_completion with 4 futures
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_normalized_difference not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow ] job step file:///calrissian/cwl.json#main/node_stac not ready
# DEBUG wait_for_completion with 2 futures
# DEBUG [job node_crop_2] initial work dir {}
# Building resources spec from {'cores': 1, 'ram': 512, 'gpus': 0}
# --------------------------------------------------------------------------------
# apiVersion: v1
# kind: Pod
# metadata:
#   labels: {}
#   name: node-crop-2-pod-ifmbomjh
# spec:
#   containers:
#   - args:
#     - python -m app --aoi -121.399,39.834,-120.74,40.472 --band nir --epsg EPSG:4326
#       --input-item https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A
#     command:
#     - /bin/sh
#     - -c
#     env:
#     - name: HOME
#       value: /UZBVYO
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PYTHONPATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /app
#     - name: TMPDIR
#       value: /tmp
#     image: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#     - ghcr.io/eoap/mastering-app-package/crop@sha256:61c2f37b3a1bd56a3eddd0f4224c72de665d42957d3325dd0397845cff198dab
#     name: node-crop-2-container
#     resources:
#       requests:
#         cpu: '1'
#         memory: 512Mi
#     volumeMounts:
#     - mountPath: /UZBVYO
#       name: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#       subPath: tmp/av4fr0cs
#     - mountPath: /tmp
#       name: tmpdir
#     workingDir: /UZBVYO
#   initContainers: []
#   nodeSelector: {}
#   restartPolicy: Never
#   securityContext:
#     runAsGroup: 0
#     runAsUser: 0
#   serviceAccountName: argo
#   volumes:
#   - name: water-bodies-detection-j6xk6-calrissian-wdir
#     persistentVolumeClaim:
#       claimName: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#   - emptyDir: {}
#     name: tmpdir
# --------------------------------------------------------------------------------
#
# DEBUG [job node_crop] initial work dir {}
# Building resources spec from {'cores': 1, 'ram': 512, 'gpus': 0}
# --------------------------------------------------------------------------------
# apiVersion: v1
# kind: Pod
# metadata:
#   labels: {}
#   name: node-crop-pod-wetidgjp
# spec:
#   containers:
#   - args:
#     - python -m app --aoi -121.399,39.834,-120.74,40.472 --band green --epsg EPSG:4326
#       --input-item https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A
#     command:
#     - /bin/sh
#     - -c
#     env:
#     - name: HOME
#       value: /UZBVYO
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PYTHONPATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /app
#     - name: TMPDIR
#       value: /tmp
#     image: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#     - ghcr.io/eoap/mastering-app-package/crop@sha256:61c2f37b3a1bd56a3eddd0f4224c72de665d42957d3325dd0397845cff198dab
#     name: node-crop-container
#     resources:
#       requests:
#         cpu: '1'
#         memory: 512Mi
#     volumeMounts:
#     - mountPath: /UZBVYO
#       name: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#       subPath: tmp/4u7v4njx
#     - mountPath: /tmp
#       name: tmpdir
#     workingDir: /UZBVYO
#   initContainers: []
#   nodeSelector: {}
#   restartPolicy: Never
#   securityContext:
#     runAsGroup: 0
#     runAsUser: 0
#   serviceAccountName: argo
#   volumes:
#   - name: water-bodies-detection-j6xk6-calrissian-wdir
#     persistentVolumeClaim:
#       claimName: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#   - emptyDir: {}
#     name: tmpdir
# --------------------------------------------------------------------------------
#
# Created k8s pod name node-crop-2-pod-ifmbomjh with id 33c509ef-9d59-4f9a-bbe4-b2e61d31db4d
# PodMonitor adding node-crop-2-pod-ifmbomjh
# k8s pod 'node-crop-2-pod-ifmbomjh' started
# pod name node-crop-2-pod-ifmbomjh with id 33c509ef-9d59-4f9a-bbe4-b2e61d31db4d has status None
# Created k8s pod name node-crop-pod-wetidgjp with id d6ec067d-13fa-4f06-a91e-b41a1937e01d
# PodMonitor adding node-crop-pod-wetidgjp
# k8s pod 'node-crop-pod-wetidgjp' started
# pod name node-crop-pod-wetidgjp with id d6ec067d-13fa-4f06-a91e-b41a1937e01d has status None
# pod name node-crop-2-pod-ifmbomjh with id 33c509ef-9d59-4f9a-bbe4-b2e61d31db4d has status {'allocated_resources': None,
#  'container_id': None,
#  'image': 'ghcr.io/eoap/mastering-app-package/crop@sha256:61c2f37b3a1bd56a3eddd0f4224c72de665d42957d3325dd0397845cff198dab',
#  'image_id': '',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-crop-2-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': None,
#            'waiting': {'message': None, 'reason': 'ContainerCreating'}}}
# pod name node-crop-pod-wetidgjp with id d6ec067d-13fa-4f06-a91e-b41a1937e01d has status {'allocated_resources': None,
#  'container_id': None,
#  'image': 'ghcr.io/eoap/mastering-app-package/crop@sha256:61c2f37b3a1bd56a3eddd0f4224c72de665d42957d3325dd0397845cff198dab',
#  'image_id': '',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-crop-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': None,
#            'waiting': {'message': None, 'reason': 'ContainerCreating'}}}
# pod name node-crop-pod-wetidgjp with id d6ec067d-13fa-4f06-a91e-b41a1937e01d has status {'allocated_resources': None,
#  'container_id': 'docker://e7f90c4bc70a7434f43ed771c39d6a0b47dee1f3cd197aeb6675040b7c900a81',
#  'image': 'sha256:337e3e9d05c61bc8df71b9ebf48749d495f8f521e3237fe13b75ba0d1a1038eb',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/crop@sha256:61c2f37b3a1bd56a3eddd0f4224c72de665d42957d3325dd0397845cff198dab',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-crop-container',
#  'ready': True,
#  'resources': None,
#  'restart_count': 0,
#  'started': True,
#  'state': {'running': {'started_at': datetime.datetime(2024, 11, 7, 6, 59, 28, tzinfo=tzlocal())},
#            'terminated': None,
#            'waiting': None}}
# [node-crop-pod-wetidgjp] follow_logs start
# pod name node-crop-2-pod-ifmbomjh with id 33c509ef-9d59-4f9a-bbe4-b2e61d31db4d has status {'allocated_resources': None,
#  'container_id': 'docker://c0bd47e078d4f134cdf9bf205f4baa6535e34703a0018397a75c8dc31e70f3d3',
#  'image': 'sha256:337e3e9d05c61bc8df71b9ebf48749d495f8f521e3237fe13b75ba0d1a1038eb',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/crop@sha256:61c2f37b3a1bd56a3eddd0f4224c72de665d42957d3325dd0397845cff198dab',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-crop-2-container',
#  'ready': True,
#  'resources': None,
#  'restart_count': 0,
#  'started': True,
#  'state': {'running': {'started_at': datetime.datetime(2024, 11, 7, 6, 59, 28, tzinfo=tzlocal())},
#            'terminated': None,
#            'waiting': None}}
# [node-crop-2-pod-ifmbomjh] follow_logs start
# [node-crop-pod-wetidgjp] 2024-11-07 06:59:29.727 | INFO     | __main__:crop:69 - Read S2A_10TFK_20210708_0_L2A from https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A
# [node-crop-pod-wetidgjp] 2024-11-07 06:59:29.753 | INFO     | __main__:crop:72 - Read asset green from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2A_10TFK_20210708_0_L2A/B03.tif
# [node-crop-2-pod-ifmbomjh] 2024-11-07 06:59:30.051 | INFO     | __main__:crop:69 - Read S2A_10TFK_20210708_0_L2A from https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A
# [node-crop-2-pod-ifmbomjh] 2024-11-07 06:59:30.101 | INFO     | __main__:crop:72 - Read asset nir from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2A_10TFK_20210708_0_L2A/B08.tif
# [node-crop-pod-wetidgjp] 2024-11-07 06:59:32.048 | INFO     | __main__:crop:90 - Crop https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2A_10TFK_20210708_0_L2A/B03.tif
# [node-crop-2-pod-ifmbomjh] 2024-11-07 06:59:32.330 | INFO     | __main__:crop:90 - Crop https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2A_10TFK_20210708_0_L2A/B08.tif
# [node-crop-2-pod-ifmbomjh] 2024-11-07 06:59:53.346 | INFO     | __main__:crop:112 - Write crop_nir.tif
# [node-crop-pod-wetidgjp] 2024-11-07 06:59:55.928 | INFO     | __main__:crop:112 - Write crop_green.tif
# [node-crop-2-pod-ifmbomjh] 2024-11-07 06:59:58.166 | INFO     | __main__:crop:115 - Done!
# [node-crop-2-pod-ifmbomjh] follow_logs end
# pod name node-crop-2-pod-ifmbomjh with id 33c509ef-9d59-4f9a-bbe4-b2e61d31db4d has status {'allocated_resources': None,
#  'container_id': 'docker://c0bd47e078d4f134cdf9bf205f4baa6535e34703a0018397a75c8dc31e70f3d3',
#  'image': 'sha256:337e3e9d05c61bc8df71b9ebf48749d495f8f521e3237fe13b75ba0d1a1038eb',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/crop@sha256:61c2f37b3a1bd56a3eddd0f4224c72de665d42957d3325dd0397845cff198dab',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-crop-2-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': {'container_id': 'docker://c0bd47e078d4f134cdf9bf205f4baa6535e34703a0018397a75c8dc31e70f3d3',
#                           'exit_code': 0,
#                           'finished_at': datetime.datetime(2024, 11, 7, 6, 59, 58, tzinfo=tzlocal()),
#                           'message': None,
#                           'reason': 'Completed',
#                           'signal': None,
#                           'started_at': datetime.datetime(2024, 11, 7, 6, 59, 28, tzinfo=tzlocal())},
#            'waiting': None}}
# Handling terminated pod name node-crop-2-pod-ifmbomjh with id 33c509ef-9d59-4f9a-bbe4-b2e61d31db4d
# handling completion with 0
# PodMonitor removing node-crop-2-pod-ifmbomjh
# os.makedirs(/calrissian/logs)
# Writing pod node_crop_2 logs to /calrissian/logs/node_crop_2.log
# shutil.rmtree(/tmp/0rlijjx1, True)
# shutil.rmtree(/tmp/m7yx_2rl, True)
# DEBUG restore [ram: 512, cores: 1, gpus 0] to available [ram: 2976.0, cores: 2.0, gpus 0]
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_normalized_difference not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow ] job step file:///calrissian/cwl.json#main/node_stac not ready
# DEBUG wait_for_completion with 1 futures
# [node-crop-pod-wetidgjp] 2024-11-07 07:00:00.506 | INFO     | __main__:crop:115 - Done!
# [node-crop-pod-wetidgjp] follow_logs end
# pod name node-crop-pod-wetidgjp with id d6ec067d-13fa-4f06-a91e-b41a1937e01d has status {'allocated_resources': None,
#  'container_id': 'docker://e7f90c4bc70a7434f43ed771c39d6a0b47dee1f3cd197aeb6675040b7c900a81',
#  'image': 'sha256:337e3e9d05c61bc8df71b9ebf48749d495f8f521e3237fe13b75ba0d1a1038eb',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/crop@sha256:61c2f37b3a1bd56a3eddd0f4224c72de665d42957d3325dd0397845cff198dab',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-crop-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': {'container_id': 'docker://e7f90c4bc70a7434f43ed771c39d6a0b47dee1f3cd197aeb6675040b7c900a81',
#                           'exit_code': 0,
#                           'finished_at': datetime.datetime(2024, 11, 7, 7, 0, tzinfo=tzlocal()),
#                           'message': None,
#                           'reason': 'Completed',
#                           'signal': None,
#                           'started_at': datetime.datetime(2024, 11, 7, 6, 59, 28, tzinfo=tzlocal())},
#            'waiting': None}}
# Handling terminated pod name node-crop-pod-wetidgjp with id d6ec067d-13fa-4f06-a91e-b41a1937e01d
# handling completion with 0
# PodMonitor removing node-crop-pod-wetidgjp
# Writing pod node_crop logs to /calrissian/logs/node_crop.log
# DEBUG [step node_crop] produced output {
#     "file:///calrissian/cwl.json#detect_water_body/node_crop/cropped": [
#         {
#             "location": "file:///calrissian/tmp/4u7v4njx/crop_green.tif",
#             "basename": "crop_green.tif",
#             "nameroot": "crop_green",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$9956fe066bc4fd47770d36b508ada24db67639e4",
#             "size": 87602514,
#             "http://commonwl.org/cwltool#generation": 0
#         },
#         {
#             "location": "file:///calrissian/tmp/av4fr0cs/crop_nir.tif",
#             "basename": "crop_nir.tif",
#             "nameroot": "crop_nir",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$295ef64b75391884bf432db41ba6e677d87ddaab",
#             "size": 100761236,
#             "http://commonwl.org/cwltool#generation": 0
#         }
#     ]
# }
# INFO [step node_crop] completed success
# shutil.rmtree(/tmp/pfsjyz4a, True)
# shutil.rmtree(/tmp/g8iyzjvc, True)
# DEBUG restore [ram: 512, cores: 1, gpus 0] to available [ram: 3488.0, cores: 3.0, gpus 0]
# INFO [workflow node_water_bodies] starting step node_normalized_difference
# DEBUG [step node_normalized_difference] job input {
#     "file:///calrissian/cwl.json#detect_water_body/node_normalized_difference/rasters": [
#         {
#             "location": "file:///calrissian/tmp/4u7v4njx/crop_green.tif",
#             "basename": "crop_green.tif",
#             "nameroot": "crop_green",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$9956fe066bc4fd47770d36b508ada24db67639e4",
#             "size": 87602514,
#             "http://commonwl.org/cwltool#generation": 0
#         },
#         {
#             "location": "file:///calrissian/tmp/av4fr0cs/crop_nir.tif",
#             "basename": "crop_nir.tif",
#             "nameroot": "crop_nir",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$295ef64b75391884bf432db41ba6e677d87ddaab",
#             "size": 100761236,
#             "http://commonwl.org/cwltool#generation": 0
#         }
#     ]
# }
# DEBUG [step node_normalized_difference] evaluated job input to {
#     "file:///calrissian/cwl.json#detect_water_body/node_normalized_difference/rasters": [
#         {
#             "location": "file:///calrissian/tmp/4u7v4njx/crop_green.tif",
#             "basename": "crop_green.tif",
#             "nameroot": "crop_green",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$9956fe066bc4fd47770d36b508ada24db67639e4",
#             "size": 87602514,
#             "http://commonwl.org/cwltool#generation": 0
#         },
#         {
#             "location": "file:///calrissian/tmp/av4fr0cs/crop_nir.tif",
#             "basename": "crop_nir.tif",
#             "nameroot": "crop_nir",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$295ef64b75391884bf432db41ba6e677d87ddaab",
#             "size": 100761236,
#             "http://commonwl.org/cwltool#generation": 0
#         }
#     ]
# }
# INFO [step node_normalized_difference] start
# DEBUG [job node_normalized_difference] initializing from file:///calrissian/cwl.json#norm_diff as part of step node_normalized_difference
# DEBUG [job node_normalized_difference] {
#     "rasters": [
#         {
#             "location": "file:///calrissian/tmp/4u7v4njx/crop_green.tif",
#             "basename": "crop_green.tif",
#             "nameroot": "crop_green",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$9956fe066bc4fd47770d36b508ada24db67639e4",
#             "size": 87602514,
#             "http://commonwl.org/cwltool#generation": 0
#         },
#         {
#             "location": "file:///calrissian/tmp/av4fr0cs/crop_nir.tif",
#             "basename": "crop_nir.tif",
#             "nameroot": "crop_nir",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$295ef64b75391884bf432db41ba6e677d87ddaab",
#             "size": 100761236,
#             "http://commonwl.org/cwltool#generation": 0
#         }
#     ]
# }
# DEBUG [job node_normalized_difference] path mappings is {
#     "file:///calrissian/tmp/4u7v4njx/crop_green.tif": [
#         "/calrissian/tmp/4u7v4njx/crop_green.tif",
#         "/var/lib/cwl/stg2ad865ac-b5d5-4f8d-a3cc-a064b1f2af3b/crop_green.tif",
#         "File",
#         true
#     ],
#     "file:///calrissian/tmp/av4fr0cs/crop_nir.tif": [
#         "/calrissian/tmp/av4fr0cs/crop_nir.tif",
#         "/var/lib/cwl/stga820488d-2a42-414a-b3ef-39163972cb7e/crop_nir.tif",
#         "File",
#         true
#     ]
# }
# DEBUG [job node_normalized_difference] command line bindings is [
#     {
#         "position": [
#             -1000000,
#             0
#         ],
#         "datum": "python"
#     },
#     {
#         "position": [
#             -1000000,
#             1
#         ],
#         "datum": "-m"
#     },
#     {
#         "position": [
#             -1000000,
#             2
#         ],
#         "datum": "app"
#     },
#     {
#         "position": [
#             1,
#             "rasters"
#         ],
#         "datum": [
#             {
#                 "location": "file:///calrissian/tmp/4u7v4njx/crop_green.tif",
#                 "basename": "crop_green.tif",
#                 "nameroot": "crop_green",
#                 "nameext": ".tif",
#                 "class": "File",
#                 "checksum": "sha1$9956fe066bc4fd47770d36b508ada24db67639e4",
#                 "size": 87602514,
#                 "http://commonwl.org/cwltool#generation": 0,
#                 "path": "/var/lib/cwl/stg2ad865ac-b5d5-4f8d-a3cc-a064b1f2af3b/crop_green.tif",
#                 "dirname": "/var/lib/cwl/stg2ad865ac-b5d5-4f8d-a3cc-a064b1f2af3b"
#             },
#             {
#                 "location": "file:///calrissian/tmp/av4fr0cs/crop_nir.tif",
#                 "basename": "crop_nir.tif",
#                 "nameroot": "crop_nir",
#                 "nameext": ".tif",
#                 "class": "File",
#                 "checksum": "sha1$295ef64b75391884bf432db41ba6e677d87ddaab",
#                 "size": 100761236,
#                 "http://commonwl.org/cwltool#generation": 0,
#                 "path": "/var/lib/cwl/stga820488d-2a42-414a-b3ef-39163972cb7e/crop_nir.tif",
#                 "dirname": "/var/lib/cwl/stga820488d-2a42-414a-b3ef-39163972cb7e"
#             }
#         ]
#     },
#     {
#         "position": [
#             1,
#             "rasters",
#             0,
#             0,
#             "rasters",
#             "rasters"
#         ],
#         "datum": {
#             "location": "file:///calrissian/tmp/4u7v4njx/crop_green.tif",
#             "basename": "crop_green.tif",
#             "nameroot": "crop_green",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$9956fe066bc4fd47770d36b508ada24db67639e4",
#             "size": 87602514,
#             "http://commonwl.org/cwltool#generation": 0,
#             "path": "/var/lib/cwl/stg2ad865ac-b5d5-4f8d-a3cc-a064b1f2af3b/crop_green.tif",
#             "dirname": "/var/lib/cwl/stg2ad865ac-b5d5-4f8d-a3cc-a064b1f2af3b"
#         }
#     },
#     {
#         "position": [
#             1,
#             "rasters",
#             1,
#             0,
#             "rasters",
#             "rasters"
#         ],
#         "datum": {
#             "location": "file:///calrissian/tmp/av4fr0cs/crop_nir.tif",
#             "basename": "crop_nir.tif",
#             "nameroot": "crop_nir",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$295ef64b75391884bf432db41ba6e677d87ddaab",
#             "size": 100761236,
#             "http://commonwl.org/cwltool#generation": 0,
#             "path": "/var/lib/cwl/stga820488d-2a42-414a-b3ef-39163972cb7e/crop_nir.tif",
#             "dirname": "/var/lib/cwl/stga820488d-2a42-414a-b3ef-39163972cb7e"
#         }
#     }
# ]
# DEBUG wait_for_completion with 0 futures
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow ] job step file:///calrissian/cwl.json#main/node_stac not ready
# DEBUG [workflow node_water_bodies] job step file:///calrissian/cwl.json#detect_water_body/node_otsu not ready
# DEBUG [workflow ] job step file:///calrissian/cwl.json#main/node_stac not ready
# DEBUG allocate [ram: 512, cores: 1, gpus 0] from available [ram: 4000.0, cores: 4.0, gpus 0]
# DEBUG wait_for_completion with 1 futures
# DEBUG [job node_normalized_difference] initial work dir {}
# Building resources spec from {'cores': 1, 'ram': 512, 'gpus': 0}
# --------------------------------------------------------------------------------
# apiVersion: v1
# kind: Pod
# metadata:
#   labels: {}
#   name: node-normalized-difference-pod-ggqiidnc
# spec:
#   containers:
#   - args:
#     - python -m app /var/lib/cwl/stg2ad865ac-b5d5-4f8d-a3cc-a064b1f2af3b/crop_green.tif
#       /var/lib/cwl/stga820488d-2a42-414a-b3ef-39163972cb7e/crop_nir.tif
#     command:
#     - /bin/sh
#     - -c
#     env:
#     - name: HOME
#       value: /UZBVYO
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PYTHONPATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /app
#     - name: TMPDIR
#       value: /tmp
#     image: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#     - ghcr.io/eoap/mastering-app-package/norm_diff@sha256:641ab55968d7f500b641969d0a7422c4c9a80dd5cc1459ee07f3e0c5ee4fa230
#     name: node-normalized-difference-container
#     resources:
#       requests:
#         cpu: '1'
#         memory: 512Mi
#     volumeMounts:
#     - mountPath: /UZBVYO
#       name: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#       subPath: tmp/i9g4leag
#     - mountPath: /tmp
#       name: tmpdir
#     - mountPath: /var/lib/cwl/stg2ad865ac-b5d5-4f8d-a3cc-a064b1f2af3b/crop_green.tif
#       name: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: true
#       subPath: tmp/4u7v4njx/crop_green.tif
#     - mountPath: /var/lib/cwl/stga820488d-2a42-414a-b3ef-39163972cb7e/crop_nir.tif
#       name: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: true
#       subPath: tmp/av4fr0cs/crop_nir.tif
#     workingDir: /UZBVYO
#   initContainers: []
#   nodeSelector: {}
#   restartPolicy: Never
#   securityContext:
#     runAsGroup: 0
#     runAsUser: 0
#   serviceAccountName: argo
#   volumes:
#   - name: water-bodies-detection-j6xk6-calrissian-wdir
#     persistentVolumeClaim:
#       claimName: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#   - emptyDir: {}
#     name: tmpdir
# --------------------------------------------------------------------------------
#
# Created k8s pod name node-normalized-difference-pod-ggqiidnc with id 1a81e63d-8173-41ce-aa17-e577a0343512
# PodMonitor adding node-normalized-difference-pod-ggqiidnc
# k8s pod 'node-normalized-difference-pod-ggqiidnc' started
# pod name node-normalized-difference-pod-ggqiidnc with id 1a81e63d-8173-41ce-aa17-e577a0343512 has status None
# pod name node-normalized-difference-pod-ggqiidnc with id 1a81e63d-8173-41ce-aa17-e577a0343512 has status {'allocated_resources': None,
#  'container_id': None,
#  'image': 'ghcr.io/eoap/mastering-app-package/norm_diff@sha256:641ab55968d7f500b641969d0a7422c4c9a80dd5cc1459ee07f3e0c5ee4fa230',
#  'image_id': '',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-normalized-difference-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': None,
#            'waiting': {'message': None, 'reason': 'ContainerCreating'}}}
# pod name node-normalized-difference-pod-ggqiidnc with id 1a81e63d-8173-41ce-aa17-e577a0343512 has status {'allocated_resources': None,
#  'container_id': 'docker://551fef420cdc221f5620c124c067e2942522e76abefed55a315304a07fffa953',
#  'image': 'sha256:9eea4fb39f705d92bb5a2ccd99c8ab1d6260155c3a51a7761c9895bc3ad64587',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/norm_diff@sha256:641ab55968d7f500b641969d0a7422c4c9a80dd5cc1459ee07f3e0c5ee4fa230',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-normalized-difference-container',
#  'ready': True,
#  'resources': None,
#  'restart_count': 0,
#  'started': True,
#  'state': {'running': {'started_at': datetime.datetime(2024, 11, 7, 7, 0, 2, tzinfo=tzlocal())},
#            'terminated': None,
#            'waiting': None}}
# [node-normalized-difference-pod-ggqiidnc] follow_logs start
# [node-normalized-difference-pod-ggqiidnc] 2024-11-07 07:00:02.738 | INFO     | __main__:normalized_difference:18 - Processing the normalized image with /var/lib/cwl/stg2ad865ac-b5d5-4f8d-a3cc-a064b1f2af3b/crop_green.tif and /var/lib/cwl/stga820488d-2a42-414a-b3ef-39163972cb7e/crop_nir.tif
# [node-normalized-difference-pod-ggqiidnc] 2024-11-07 07:00:04.034 | INFO     | __main__:normalized_difference:39 - Write norm_diff.tif
# [node-normalized-difference-pod-ggqiidnc] 2024-11-07 07:00:10.007 | INFO     | __main__:normalized_difference:42 - Done!
# [node-normalized-difference-pod-ggqiidnc] follow_logs end
# pod name node-normalized-difference-pod-ggqiidnc with id 1a81e63d-8173-41ce-aa17-e577a0343512 has status {'allocated_resources': None,
#  'container_id': 'docker://551fef420cdc221f5620c124c067e2942522e76abefed55a315304a07fffa953',
#  'image': 'sha256:9eea4fb39f705d92bb5a2ccd99c8ab1d6260155c3a51a7761c9895bc3ad64587',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/norm_diff@sha256:641ab55968d7f500b641969d0a7422c4c9a80dd5cc1459ee07f3e0c5ee4fa230',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-normalized-difference-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': {'container_id': 'docker://551fef420cdc221f5620c124c067e2942522e76abefed55a315304a07fffa953',
#                           'exit_code': 0,
#                           'finished_at': datetime.datetime(2024, 11, 7, 7, 0, 10, tzinfo=tzlocal()),
#                           'message': None,
#                           'reason': 'Completed',
#                           'signal': None,
#                           'started_at': datetime.datetime(2024, 11, 7, 7, 0, 2, tzinfo=tzlocal())},
#            'waiting': None}}
# Handling terminated pod name node-normalized-difference-pod-ggqiidnc with id 1a81e63d-8173-41ce-aa17-e577a0343512
# handling completion with 0
# PodMonitor removing node-normalized-difference-pod-ggqiidnc
# Writing pod node_normalized_difference logs to /calrissian/logs/node_normalized_difference.log
# DEBUG [step node_normalized_difference] produced output {
#     "file:///calrissian/cwl.json#detect_water_body/node_normalized_difference/ndwi": {
#         "location": "file:///calrissian/tmp/i9g4leag/norm_diff.tif",
#         "basename": "norm_diff.tif",
#         "nameroot": "norm_diff",
#         "nameext": ".tif",
#         "class": "File",
#         "checksum": "sha1$8a8000c4b3fa09be2364ce009710c11124d009ca",
#         "size": 224221619,
#         "http://commonwl.org/cwltool#generation": 0
#     }
# }
# INFO [step node_normalized_difference] completed success
# shutil.rmtree(/tmp/6w6uidh3, True)
# shutil.rmtree(/tmp/d19d3tr5, True)
# DEBUG restore [ram: 512, cores: 1, gpus 0] to available [ram: 3488.0, cores: 3.0, gpus 0]
# INFO [workflow node_water_bodies] starting step node_otsu
# DEBUG [step node_otsu] job input {
#     "file:///calrissian/cwl.json#detect_water_body/node_otsu/raster": {
#         "location": "file:///calrissian/tmp/i9g4leag/norm_diff.tif",
#         "basename": "norm_diff.tif",
#         "nameroot": "norm_diff",
#         "nameext": ".tif",
#         "class": "File",
#         "checksum": "sha1$8a8000c4b3fa09be2364ce009710c11124d009ca",
#         "size": 224221619,
#         "http://commonwl.org/cwltool#generation": 0
#     }
# }
# DEBUG [step node_otsu] evaluated job input to {
#     "file:///calrissian/cwl.json#detect_water_body/node_otsu/raster": {
#         "location": "file:///calrissian/tmp/i9g4leag/norm_diff.tif",
#         "basename": "norm_diff.tif",
#         "nameroot": "norm_diff",
#         "nameext": ".tif",
#         "class": "File",
#         "checksum": "sha1$8a8000c4b3fa09be2364ce009710c11124d009ca",
#         "size": 224221619,
#         "http://commonwl.org/cwltool#generation": 0
#     }
# }
# INFO [step node_otsu] start
# DEBUG [job node_otsu] initializing from file:///calrissian/cwl.json#otsu as part of step node_otsu
# DEBUG [job node_otsu] {
#     "raster": {
#         "location": "file:///calrissian/tmp/i9g4leag/norm_diff.tif",
#         "basename": "norm_diff.tif",
#         "nameroot": "norm_diff",
#         "nameext": ".tif",
#         "class": "File",
#         "checksum": "sha1$8a8000c4b3fa09be2364ce009710c11124d009ca",
#         "size": 224221619,
#         "http://commonwl.org/cwltool#generation": 0
#     }
# }
# DEBUG [job node_otsu] path mappings is {
#     "file:///calrissian/tmp/i9g4leag/norm_diff.tif": [
#         "/calrissian/tmp/i9g4leag/norm_diff.tif",
#         "/var/lib/cwl/stg1af840fd-1a9a-4ad4-8ecd-c1481a82c5a9/norm_diff.tif",
#         "File",
#         true
#     ]
# }
# DEBUG [job node_otsu] command line bindings is [
#     {
#         "position": [
#             -1000000,
#             0
#         ],
#         "datum": "python"
#     },
#     {
#         "position": [
#             -1000000,
#             1
#         ],
#         "datum": "-m"
#     },
#     {
#         "position": [
#             -1000000,
#             2
#         ],
#         "datum": "app"
#     },
#     {
#         "position": [
#             1,
#             "raster"
#         ],
#         "datum": {
#             "location": "file:///calrissian/tmp/i9g4leag/norm_diff.tif",
#             "basename": "norm_diff.tif",
#             "nameroot": "norm_diff",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$8a8000c4b3fa09be2364ce009710c11124d009ca",
#             "size": 224221619,
#             "http://commonwl.org/cwltool#generation": 0,
#             "path": "/var/lib/cwl/stg1af840fd-1a9a-4ad4-8ecd-c1481a82c5a9/norm_diff.tif",
#             "dirname": "/var/lib/cwl/stg1af840fd-1a9a-4ad4-8ecd-c1481a82c5a9"
#         }
#     }
# ]
# DEBUG wait_for_completion with 0 futures
# DEBUG [workflow ] job step file:///calrissian/cwl.json#main/node_stac not ready
# DEBUG [workflow ] job step file:///calrissian/cwl.json#main/node_stac not ready
# DEBUG allocate [ram: 512, cores: 1, gpus 0] from available [ram: 4000.0, cores: 4.0, gpus 0]
# DEBUG wait_for_completion with 1 futures
# DEBUG [job node_otsu] initial work dir {}
# Building resources spec from {'cores': 1, 'ram': 512, 'gpus': 0}
# --------------------------------------------------------------------------------
# apiVersion: v1
# kind: Pod
# metadata:
#   labels: {}
#   name: node-otsu-pod-hyomubhh
# spec:
#   containers:
#   - args:
#     - python -m app /var/lib/cwl/stg1af840fd-1a9a-4ad4-8ecd-c1481a82c5a9/norm_diff.tif
#     command:
#     - /bin/sh
#     - -c
#     env:
#     - name: HOME
#       value: /UZBVYO
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PYTHONPATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /app
#     - name: TMPDIR
#       value: /tmp
#     image: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#     - ghcr.io/eoap/mastering-app-package/otsu@sha256:ec02baf6a007ebb5a2dc037af2da8ef94db67bb8a6139682ad61041f9d27c779
#     name: node-otsu-container
#     resources:
#       requests:
#         cpu: '1'
#         memory: 512Mi
#     volumeMounts:
#     - mountPath: /UZBVYO
#       name: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#       subPath: tmp/jww_z151
#     - mountPath: /tmp
#       name: tmpdir
#     - mountPath: /var/lib/cwl/stg1af840fd-1a9a-4ad4-8ecd-c1481a82c5a9/norm_diff.tif
#       name: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: true
#       subPath: tmp/i9g4leag/norm_diff.tif
#     workingDir: /UZBVYO
#   initContainers: []
#   nodeSelector: {}
#   restartPolicy: Never
#   securityContext:
#     runAsGroup: 0
#     runAsUser: 0
#   serviceAccountName: argo
#   volumes:
#   - name: water-bodies-detection-j6xk6-calrissian-wdir
#     persistentVolumeClaim:
#       claimName: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#   - emptyDir: {}
#     name: tmpdir
# --------------------------------------------------------------------------------
#
# Created k8s pod name node-otsu-pod-hyomubhh with id f7f6b06f-93d0-4db8-8e76-3446b8c99151
# PodMonitor adding node-otsu-pod-hyomubhh
# k8s pod 'node-otsu-pod-hyomubhh' started
# pod name node-otsu-pod-hyomubhh with id f7f6b06f-93d0-4db8-8e76-3446b8c99151 has status None
# pod name node-otsu-pod-hyomubhh with id f7f6b06f-93d0-4db8-8e76-3446b8c99151 has status {'allocated_resources': None,
#  'container_id': None,
#  'image': 'ghcr.io/eoap/mastering-app-package/otsu@sha256:ec02baf6a007ebb5a2dc037af2da8ef94db67bb8a6139682ad61041f9d27c779',
#  'image_id': '',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-otsu-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': None,
#            'waiting': {'message': None, 'reason': 'ContainerCreating'}}}
# pod name node-otsu-pod-hyomubhh with id f7f6b06f-93d0-4db8-8e76-3446b8c99151 has status {'allocated_resources': None,
#  'container_id': 'docker://8940f35946ec15d1a6bec4a53755fbe15d71ae723d9025c011e65ab0bc28ad1f',
#  'image': 'sha256:30f412cc580cc072605130893c652082fbbcf68ac6f02984468b492361ad787c',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/otsu@sha256:ec02baf6a007ebb5a2dc037af2da8ef94db67bb8a6139682ad61041f9d27c779',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-otsu-container',
#  'ready': True,
#  'resources': None,
#  'restart_count': 0,
#  'started': True,
#  'state': {'running': {'started_at': datetime.datetime(2024, 11, 7, 7, 0, 11, tzinfo=tzlocal())},
#            'terminated': None,
#            'waiting': None}}
# [node-otsu-pod-hyomubhh] follow_logs start
# [node-otsu-pod-hyomubhh] 2024-11-07 07:00:13.369 | INFO     | __main__:otsu:37 - Applying the Otsu threshold to /var/lib/cwl/stg1af840fd-1a9a-4ad4-8ecd-c1481a82c5a9/norm_diff.tif
# [node-otsu-pod-hyomubhh] 2024-11-07 07:00:13.374 | INFO     | __main__:otsu:40 - Write otsu.tif
# [node-otsu-pod-hyomubhh] 2024-11-07 07:00:14.769 | INFO     | __main__:otsu:43 - Done!
# [node-otsu-pod-hyomubhh] follow_logs end
# pod name node-otsu-pod-hyomubhh with id f7f6b06f-93d0-4db8-8e76-3446b8c99151 has status {'allocated_resources': None,
#  'container_id': 'docker://8940f35946ec15d1a6bec4a53755fbe15d71ae723d9025c011e65ab0bc28ad1f',
#  'image': 'sha256:30f412cc580cc072605130893c652082fbbcf68ac6f02984468b492361ad787c',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/otsu@sha256:ec02baf6a007ebb5a2dc037af2da8ef94db67bb8a6139682ad61041f9d27c779',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-otsu-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': {'container_id': 'docker://8940f35946ec15d1a6bec4a53755fbe15d71ae723d9025c011e65ab0bc28ad1f',
#                           'exit_code': 0,
#                           'finished_at': datetime.datetime(2024, 11, 7, 7, 0, 14, tzinfo=tzlocal()),
#                           'message': None,
#                           'reason': 'Completed',
#                           'signal': None,
#                           'started_at': datetime.datetime(2024, 11, 7, 7, 0, 11, tzinfo=tzlocal())},
#            'waiting': None}}
# Handling terminated pod name node-otsu-pod-hyomubhh with id f7f6b06f-93d0-4db8-8e76-3446b8c99151
# handling completion with 0
# PodMonitor removing node-otsu-pod-hyomubhh
# Writing pod node_otsu logs to /calrissian/logs/node_otsu.log
# DEBUG [step node_otsu] produced output {
#     "file:///calrissian/cwl.json#detect_water_body/node_otsu/binary_mask_item": {
#         "location": "file:///calrissian/tmp/jww_z151/otsu.tif",
#         "basename": "otsu.tif",
#         "nameroot": "otsu",
#         "nameext": ".tif",
#         "class": "File",
#         "checksum": "sha1$210598cf619d49eabfdc24414bd445f59668f3bd",
#         "size": 289288,
#         "http://commonwl.org/cwltool#generation": 0
#     }
# }
# INFO [step node_otsu] completed success
# INFO [workflow node_water_bodies] completed success
# DEBUG [workflow node_water_bodies] outputs {
#     "detected_water_body": {
#         "location": "file:///calrissian/tmp/jww_z151/otsu.tif",
#         "basename": "otsu.tif",
#         "nameroot": "otsu",
#         "nameext": ".tif",
#         "class": "File",
#         "checksum": "sha1$210598cf619d49eabfdc24414bd445f59668f3bd",
#         "size": 289288,
#         "http://commonwl.org/cwltool#generation": 0
#     }
# }
# DEBUG [step node_water_bodies] produced output {
#     "file:///calrissian/cwl.json#main/node_water_bodies/detected_water_body": [
#         {
#             "location": "file:///calrissian/tmp/jww_z151/otsu.tif",
#             "basename": "otsu.tif",
#             "nameroot": "otsu",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$210598cf619d49eabfdc24414bd445f59668f3bd",
#             "size": 289288,
#             "http://commonwl.org/cwltool#generation": 0
#         }
#     ]
# }
# INFO [step node_water_bodies] completed success
# shutil.rmtree(/tmp/__deblho, True)
# shutil.rmtree(/tmp/uvail6ac, True)
# DEBUG restore [ram: 512, cores: 1, gpus 0] to available [ram: 3488.0, cores: 3.0, gpus 0]
# INFO [workflow ] starting step node_stac
# DEBUG [step node_stac] job input {
#     "file:///calrissian/cwl.json#main/node_stac/item": [
#         "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
#     ],
#     "file:///calrissian/cwl.json#main/node_stac/rasters": [
#         {
#             "location": "file:///calrissian/tmp/jww_z151/otsu.tif",
#             "basename": "otsu.tif",
#             "nameroot": "otsu",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$210598cf619d49eabfdc24414bd445f59668f3bd",
#             "size": 289288,
#             "http://commonwl.org/cwltool#generation": 0
#         }
#     ]
# }
# DEBUG [step node_stac] evaluated job input to {
#     "file:///calrissian/cwl.json#main/node_stac/item": [
#         "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
#     ],
#     "file:///calrissian/cwl.json#main/node_stac/rasters": [
#         {
#             "location": "file:///calrissian/tmp/jww_z151/otsu.tif",
#             "basename": "otsu.tif",
#             "nameroot": "otsu",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$210598cf619d49eabfdc24414bd445f59668f3bd",
#             "size": 289288,
#             "http://commonwl.org/cwltool#generation": 0
#         }
#     ]
# }
# INFO [step node_stac] start
# DEBUG [job node_stac] initializing from file:///calrissian/cwl.json#stac as part of step node_stac
# DEBUG [job node_stac] {
#     "item": [
#         "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
#     ],
#     "rasters": [
#         {
#             "location": "file:///calrissian/tmp/jww_z151/otsu.tif",
#             "basename": "otsu.tif",
#             "nameroot": "otsu",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$210598cf619d49eabfdc24414bd445f59668f3bd",
#             "size": 289288,
#             "http://commonwl.org/cwltool#generation": 0
#         }
#     ]
# }
# DEBUG [job node_stac] path mappings is {
#     "file:///calrissian/tmp/jww_z151/otsu.tif": [
#         "/calrissian/tmp/jww_z151/otsu.tif",
#         "/var/lib/cwl/stg695cad4f-603e-4c64-8563-bc8dd4005238/otsu.tif",
#         "File",
#         true
#     ]
# }
# DEBUG [job node_stac] command line bindings is [
#     {
#         "position": [
#             -1000000,
#             0
#         ],
#         "datum": "python"
#     },
#     {
#         "position": [
#             -1000000,
#             1
#         ],
#         "datum": "-m"
#     },
#     {
#         "position": [
#             -1000000,
#             2
#         ],
#         "datum": "app"
#     },
#     {
#         "prefix": "--input-item",
#         "position": [
#             0,
#             0,
#             "item",
#             "item"
#         ],
#         "datum": "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"
#     },
#     {
#         "prefix": "--water-body",
#         "position": [
#             0,
#             0,
#             "rasters",
#             "rasters"
#         ],
#         "datum": {
#             "location": "file:///calrissian/tmp/jww_z151/otsu.tif",
#             "basename": "otsu.tif",
#             "nameroot": "otsu",
#             "nameext": ".tif",
#             "class": "File",
#             "checksum": "sha1$210598cf619d49eabfdc24414bd445f59668f3bd",
#             "size": 289288,
#             "http://commonwl.org/cwltool#generation": 0,
#             "path": "/var/lib/cwl/stg695cad4f-603e-4c64-8563-bc8dd4005238/otsu.tif",
#             "dirname": "/var/lib/cwl/stg695cad4f-603e-4c64-8563-bc8dd4005238"
#         }
#     }
# ]
# DEBUG wait_for_completion with 0 futures
# DEBUG allocate [ram: 512, cores: 1, gpus 0] from available [ram: 4000.0, cores: 4.0, gpus 0]
# DEBUG wait_for_completion with 1 futures
# DEBUG [job node_stac] initial work dir {}
# Building resources spec from {'cores': 1, 'ram': 512, 'gpus': 0}
# --------------------------------------------------------------------------------
# apiVersion: v1
# kind: Pod
# metadata:
#   labels: {}
#   name: node-stac-pod-xdmuuseo
# spec:
#   containers:
#   - args:
#     - python -m app --input-item https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A
#       --water-body /var/lib/cwl/stg695cad4f-603e-4c64-8563-bc8dd4005238/otsu.tif
#     command:
#     - /bin/sh
#     - -c
#     env:
#     - name: HOME
#       value: /UZBVYO
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
#     - name: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - PYTHONPATH
#       value: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#       - /app
#     - name: TMPDIR
#       value: /tmp
#     image: !!python/object/new:ruamel.yaml.scalarstring.DoubleQuotedScalarString
#     - ghcr.io/eoap/mastering-app-package/stac@sha256:8ad7e7d6999c0c4c91c2b19ce231f24734d2af8f41b855ef9a06276d23345601
#     name: node-stac-container
#     resources:
#       requests:
#         cpu: '1'
#         memory: 512Mi
#     volumeMounts:
#     - mountPath: /UZBVYO
#       name: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#       subPath: tmp/64geu8b8
#     - mountPath: /tmp
#       name: tmpdir
#     - mountPath: /var/lib/cwl/stg695cad4f-603e-4c64-8563-bc8dd4005238/otsu.tif
#       name: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: true
#       subPath: tmp/jww_z151/otsu.tif
#     workingDir: /UZBVYO
#   initContainers: []
#   nodeSelector: {}
#   restartPolicy: Never
#   securityContext:
#     runAsGroup: 0
#     runAsUser: 0
#   serviceAccountName: argo
#   volumes:
#   - name: water-bodies-detection-j6xk6-calrissian-wdir
#     persistentVolumeClaim:
#       claimName: water-bodies-detection-j6xk6-calrissian-wdir
#       readOnly: false
#   - emptyDir: {}
#     name: tmpdir
# --------------------------------------------------------------------------------
#
# Created k8s pod name node-stac-pod-xdmuuseo with id 76241aac-cb51-4e0a-8aa2-08262e192b82
# PodMonitor adding node-stac-pod-xdmuuseo
# k8s pod 'node-stac-pod-xdmuuseo' started
# pod name node-stac-pod-xdmuuseo with id 76241aac-cb51-4e0a-8aa2-08262e192b82 has status None
# pod name node-stac-pod-xdmuuseo with id 76241aac-cb51-4e0a-8aa2-08262e192b82 has status {'allocated_resources': None,
#  'container_id': None,
#  'image': 'ghcr.io/eoap/mastering-app-package/stac@sha256:8ad7e7d6999c0c4c91c2b19ce231f24734d2af8f41b855ef9a06276d23345601',
#  'image_id': '',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-stac-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': None,
#            'waiting': {'message': None, 'reason': 'ContainerCreating'}}}
# pod name node-stac-pod-xdmuuseo with id 76241aac-cb51-4e0a-8aa2-08262e192b82 has status {'allocated_resources': None,
#  'container_id': 'docker://2622d1171446e414144a83b887bb0e0212a76188a6cc1c9fe6cd20c6c9115a57',
#  'image': 'sha256:49137993bbc6c46dfaa4456e2f576ff7a093fade098e2e6499b3dcf210b69bcb',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/stac@sha256:8ad7e7d6999c0c4c91c2b19ce231f24734d2af8f41b855ef9a06276d23345601',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-stac-container',
#  'ready': True,
#  'resources': None,
#  'restart_count': 0,
#  'started': True,
#  'state': {'running': {'started_at': datetime.datetime(2024, 11, 7, 7, 0, 16, tzinfo=tzlocal())},
#            'terminated': None,
#            'waiting': None}}
# [node-stac-pod-xdmuuseo] follow_logs start
# [node-stac-pod-xdmuuseo] 2024-11-07 07:00:16.975 | INFO     | __main__:to_stac:31 - Creating a STAC Catalog for /var/lib/cwl/stg695cad4f-603e-4c64-8563-bc8dd4005238/otsu.tif
# [node-stac-pod-xdmuuseo] 2024-11-07 07:00:17.611 | INFO     | __main__:to_stac:62 - Done!
# [node-stac-pod-xdmuuseo] follow_logs end
# pod name node-stac-pod-xdmuuseo with id 76241aac-cb51-4e0a-8aa2-08262e192b82 has status {'allocated_resources': None,
#  'container_id': 'docker://2622d1171446e414144a83b887bb0e0212a76188a6cc1c9fe6cd20c6c9115a57',
#  'image': 'sha256:49137993bbc6c46dfaa4456e2f576ff7a093fade098e2e6499b3dcf210b69bcb',
#  'image_id': 'docker-pullable://ghcr.io/eoap/mastering-app-package/stac@sha256:8ad7e7d6999c0c4c91c2b19ce231f24734d2af8f41b855ef9a06276d23345601',
#  'last_state': {'running': None, 'terminated': None, 'waiting': None},
#  'name': 'node-stac-container',
#  'ready': False,
#  'resources': None,
#  'restart_count': 0,
#  'started': False,
#  'state': {'running': None,
#            'terminated': {'container_id': 'docker://2622d1171446e414144a83b887bb0e0212a76188a6cc1c9fe6cd20c6c9115a57',
#                           'exit_code': 0,
#                           'finished_at': datetime.datetime(2024, 11, 7, 7, 0, 17, tzinfo=tzlocal()),
#                           'message': None,
#                           'reason': 'Completed',
#                           'signal': None,
#                           'started_at': datetime.datetime(2024, 11, 7, 7, 0, 16, tzinfo=tzlocal())},
#            'waiting': None}}
# Handling terminated pod name node-stac-pod-xdmuuseo with id 76241aac-cb51-4e0a-8aa2-08262e192b82
# handling completion with 0
# PodMonitor removing node-stac-pod-xdmuuseo
# Writing pod node_stac logs to /calrissian/logs/node_stac.log
# DEBUG [step node_stac] produced output {
#     "file:///calrissian/cwl.json#main/node_stac/stac_catalog": {
#         "location": "file:///calrissian/tmp/64geu8b8",
#         "basename": "64geu8b8",
#         "nameroot": "64geu8b8",
#         "nameext": "",
#         "class": "Directory"
#     }
# }
# INFO [step node_stac] completed success
# INFO [workflow ] completed success
# DEBUG [workflow ] outputs {
#     "stac_catalog": {
#         "location": "file:///calrissian/tmp/64geu8b8",
#         "basename": "64geu8b8",
#         "nameroot": "64geu8b8",
#         "nameext": "",
#         "class": "Directory"
#     }
# }
# shutil.rmtree(/tmp/nk77le6c, True)
# shutil.rmtree(/tmp/1nro91tf, True)
# DEBUG restore [ram: 512, cores: 1, gpus 0] to available [ram: 3488.0, cores: 3.0, gpus 0]
# DEBUG wait_for_completion with 0 futures
# DEBUG wait_for_completion with 0 futures
# DEBUG Finishing ThreadPoolExecutor.run_jobs: total_resources=[ram: 4000.0, cores: 4.0, gpus 0], available_resources=[ram: 4000.0, cores: 4.0, gpus 0]
# DEBUG Moving /calrissian/tmp/64geu8b8 to /calrissian/results/64geu8b8
# DEBUG Removing intermediate output directory /calrissian/tmp/i9g4leag
# DEBUG Removing intermediate output directory /calrissian/tmp/4u7v4njx
# DEBUG Removing intermediate output directory /calrissian/tmp/8n6ynwjj
# DEBUG Removing intermediate output directory /calrissian/tmp/jww_z151
# DEBUG Removing intermediate output directory /calrissian/tmp/av4fr0cs
# DEBUG Removing intermediate output directory /calrissian/tmp/r6iubpid
# INFO Final process status is success
# Starting Cleanup
# Finishing Cleanup
# ---
# id: usage-report
# description: Usage report produced by the CWL execution
# value: {
#     "cores_allowed": 4.0,
#     "ram_mb_allowed": 4000.0,
#     "children": [
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 100.761236,
#             "exit_code": 0,
#             "name": "node_crop_2",
#             "start_time": "2024-11-07T06:59:28+00:00",
#             "finish_time": "2024-11-07T06:59:58+00:00",
#             "elapsed_hours": 0.008333333333333333,
#             "elapsed_seconds": 30.0,
#             "ram_megabyte_hours": 4.473924266666667,
#             "cpu_hours": 0.008333333333333333
#         },
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 87.602514,
#             "exit_code": 0,
#             "name": "node_crop",
#             "start_time": "2024-11-07T06:59:28+00:00",
#             "finish_time": "2024-11-07T07:00:00+00:00",
#             "elapsed_hours": 0.008888888888888889,
#             "elapsed_seconds": 32.0,
#             "ram_megabyte_hours": 4.772185884444444,
#             "cpu_hours": 0.008888888888888889
#         },
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 224.221619,
#             "exit_code": 0,
#             "name": "node_normalized_difference",
#             "start_time": "2024-11-07T07:00:02+00:00",
#             "finish_time": "2024-11-07T07:00:10+00:00",
#             "elapsed_hours": 0.0022222222222222222,
#             "elapsed_seconds": 8.0,
#             "ram_megabyte_hours": 1.193046471111111,
#             "cpu_hours": 0.0022222222222222222
#         },
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 0.289288,
#             "exit_code": 0,
#             "name": "node_otsu",
#             "start_time": "2024-11-07T07:00:11+00:00",
#             "finish_time": "2024-11-07T07:00:14+00:00",
#             "elapsed_hours": 0.0008333333333333334,
#             "elapsed_seconds": 3.0,
#             "ram_megabyte_hours": 0.4473924266666667,
#             "cpu_hours": 0.0008333333333333334
#         },
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 0.0,
#             "exit_code": 0,
#             "name": "node_stac",
#             "start_time": "2024-11-07T07:00:16+00:00",
#             "finish_time": "2024-11-07T07:00:17+00:00",
#             "elapsed_hours": 0.0002777777777777778,
#             "elapsed_seconds": 1.0,
#             "ram_megabyte_hours": 0.14913080888888888,
#             "cpu_hours": 0.0002777777777777778
#         }
#     ],
#     "start_time": "2024-11-07T06:59:28+00:00",
#     "finish_time": "2024-11-07T07:00:17+00:00",
#     "elapsed_hours": 0.01361111111111111,
#     "elapsed_seconds": 49.0,
#     "total_cpu_hours": 0.020555555555555553,
#     "total_ram_megabyte_hours": 11.03567985777778,
#     "total_disk_megabytes": 412.874657,
#     "total_tasks": 5,
#     "max_parallel_cpus": 2.0,
#     "max_parallel_ram_megabytes": 1073.741824,
#     "max_parallel_tasks": 2
# }
# ---
# id: stac-catalog
# description: STAC catalog with the detected water bodies and published on S3
# value: s3://results/water-bodies-detection-j6xk6-d0c9e3c4-67e9-4e4e-9479-454a5d31dff0/catalog.json
# ---

# %% [markdown]
# List the "job" outputs artifacts

# %%
for artifact in workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("artifacts"):
    print(f"id: {artifact['name']}")
    print(f"location in artifact bucket: {artifact.get('s3').get('key')}")
    print("---")
# Out:
# id: tool-logs
# location in artifact bucket: water-bodies-detection-j6xk6-d0c9e3c4-67e9-4e4e-9479-454a5d31dff0-artifacts/tool-logs.tgz
# ---
# id: calrissian-output
# location in artifact bucket: water-bodies-detection-j6xk6-d0c9e3c4-67e9-4e4e-9479-454a5d31dff0-artifacts/calrissian-output.tgz
# ---
# id: calrissian-stderr
# location in artifact bucket: water-bodies-detection-j6xk6-d0c9e3c4-67e9-4e4e-9479-454a5d31dff0-artifacts/calrissian-stderr.tgz
# ---
# id: calrissian-report
# location in artifact bucket: water-bodies-detection-j6xk6-d0c9e3c4-67e9-4e4e-9479-454a5d31dff0-artifacts/calrissian-report.tgz
# ---

# %%
workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("artifacts")
# Out:
# [{'name': 'tool-logs',
#   'path': '/calrissian/logs',
#   's3': {'key': 'water-bodies-detection-j6xk6-d0c9e3c4-67e9-4e4e-9479-454a5d31dff0-artifacts/tool-logs.tgz'}},
#  {'name': 'calrissian-output',
#   'path': '/tmp/calrissian-output.json',
#   's3': {'key': 'water-bodies-detection-j6xk6-d0c9e3c4-67e9-4e4e-9479-454a5d31dff0-artifacts/calrissian-output.tgz'}},
#  {'name': 'calrissian-stderr',
#   'path': '/tmp/calrissian-stderr.txt',
#   's3': {'key': 'water-bodies-detection-j6xk6-d0c9e3c4-67e9-4e4e-9479-454a5d31dff0-artifacts/calrissian-stderr.tgz'}},
#  {'name': 'calrissian-report',
#   'path': '/tmp/calrissian-report.json',
#   's3': {'key': 'water-bodies-detection-j6xk6-d0c9e3c4-67e9-4e4e-9479-454a5d31dff0-artifacts/calrissian-report.tgz'}}]

# %% [markdown]
# ## Download the "job" artifacts

# %%
[artifact.get("name") for artifact in workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("artifacts")]
# Out:
# ['tool-logs', 'calrissian-output', 'calrissian-stderr', 'calrissian-report']

# %%
# Configuration

id_discriminator = "workflows"
id = job_name
node_id = job_name
ARTIFACT_BASE_URL = f"http://localhost:2746/artifact-files/{NAMESPACE}/{id_discriminator}/{id}/{node_id}/outputs" #/tool-logs"


# Headers for authentication
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}"
}

# Download the artifacts
for artifact in workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("artifacts"):
    
    print(f"API endpoint: GET {ARTIFACT_BASE_URL}/{artifact.get('name')}")
    response = requests.get(f"{ARTIFACT_BASE_URL}/{artifact.get('name')}", headers=headers, stream=True)

    output_file = f"{artifact.get('name')}.tar.gz"  
    if response.status_code == 200:
        with open(output_file, "wb") as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
        print(f"Artifact downloaded successfully and saved as {output_file}")
    else:
        print(f"Failed to download artifact. Status code: {response.status_code}")
        print(response.text)
# Out:
# API endpoint: GET http://localhost:2746/artifact-files/ns1/workflows/water-bodies-detection-j6xk6/water-bodies-detection-j6xk6/outputs/tool-logs
# Artifact downloaded successfully and saved as tool-logs.tar.gz
# API endpoint: GET http://localhost:2746/artifact-files/ns1/workflows/water-bodies-detection-j6xk6/water-bodies-detection-j6xk6/outputs/calrissian-output
# Artifact downloaded successfully and saved as calrissian-output.tar.gz
# API endpoint: GET http://localhost:2746/artifact-files/ns1/workflows/water-bodies-detection-j6xk6/water-bodies-detection-j6xk6/outputs/calrissian-stderr
# Artifact downloaded successfully and saved as calrissian-stderr.tar.gz
# API endpoint: GET http://localhost:2746/artifact-files/ns1/workflows/water-bodies-detection-j6xk6/water-bodies-detection-j6xk6/outputs/calrissian-report
# Artifact downloaded successfully and saved as calrissian-report.tar.gz

# %% [markdown]
# ## Delete "Job"

# %%
print(f"API endpoint: DELETE {ARGO_SERVER_URL}/workflows/{NAMESPACE}/{job_name}S")

response = requests.delete(f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}/{job_name}", headers=headers)

print(response.status_code)
# Out:
# API endpoint: DELETE http://localhost:2746/api/v1/workflows/ns1/water-bodies-detection-j6xk6S
# 200

# %% [markdown]
# Check the "job" no longer exists:

# %%
response = requests.get(f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}/{job_name}", headers=headers)

response.status_code
# Out:
# 404
