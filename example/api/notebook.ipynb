# %%
import requests
import time
import os
import requests
import json

# %%
# Configuration
NAMESPACE = "ns1"
ARGO_SERVER_URL = f"http://localhost:2746/api/v1"

# this token is generated by the argo server with the following command:
# kubectl get -n ns1 secret argo.service-account-token -o=jsonpath='{.data.token}' | base64 --decode
AUTH_TOKEN = "eyJhbGciOiJSUzI1NiIsImtpZCI6ImNtR2dMYUdaLWk4MS1IbjkyNWs3ejhrMkl3VFdOZWZnRS12QzdfdkwtTGsifQ.....Bxe3oPSK_pjjfanfeSskJ4QMFaVr6joDBbugBuDNS2KYzEFOkcaaUXaGmSXTqIsRPc1VWCrl9hKHrJL2I4mPsIA-AmxLcjh0N2I0Gvj_DRuqWhcAu1ENVT8Gtme5m7iZ6dyjS6_M-agfV9QmhADjowmW58gQwMlEVdXnAw_LISwFBUFX2_CNnw5sOFrpADVP7C7ksa8Q0IUHJebTpMTeDmTaJv-pBd2c7nbdLAoDnzKCD27LUcmGZJruieOJccLXztsHQfD8v3lz7KIBH2264cyHUH74AQIlR1WDWMDEu6xZCdHhmQ2fRT12GlyXZB7DsYhuw575qqtpdRs6Y2qa2w"

# %% [markdown]
# ## List available "Processes"
#
# ```
# API endpoint: GET http://localhost:2746/api/v1/workflow-templates/{namespace}
# ```

# %%
# Headers for API request
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
}

print(f"API endpoint: GET {ARGO_SERVER_URL}/workflow-templates/{NAMESPACE}")

response = requests.get(f"{ARGO_SERVER_URL}/workflow-templates/{NAMESPACE}", headers=headers)

print(response.status_code)
# Out:
# API endpoint: GET http://localhost:2746/api/v1/workflow-templates/ns1
# 200

# %% [markdown]
# Get information about the available "Processes"

# %%
response.json().get("items", {})

for item in response.json().get("items", {}):
    print(item.get("metadata", {}).get("name", {}))
    print(item.get("metadata", {}).get("annotations", {}).get("workflows.argoproj.io/description", {}))
    print(item.get("metadata", {}).get("annotations", {}).get("eoap.ogc.org/version", "N/A"))
    print("---")
# Out:
# argo-cwl-runner
# This workflow template is a CWL runner for Argo Workflows.
#
# N/A
# ---
# water-bodies-detection
# This workflow template detects water bodies.
#
# 1.0.0
# ---

# %% [markdown]
# ## Describe "Process"
#
# ```
# API endpoint: GET http://localhost:2746/api/v1/workflow-templates/{namespace}/{name}
# ```

# %%
id = "water-bodies-detection"

# Headers for API request
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
}

print(f"API endpoint: GET {ARGO_SERVER_URL}/workflow-templates/{NAMESPACE}/{id}")

response = requests.get(f"{ARGO_SERVER_URL}/workflow-templates/{NAMESPACE}/{id}", headers=headers)

print(response.status_code)
# Out:
# API endpoint: GET http://localhost:2746/api/v1/workflow-templates/ns1/water-bodies-detection
# 200

# %% [markdown]
# "Processes" have an entrypoint:

# %%
entry_point = response.json().get("spec", {}).get("entrypoint", None)

entry_point
# Out:
# 'main'

# %% [markdown]
# Get the "Process" entry point template:

# %%
[template for template in response.json().get("spec", {}).get("templates", {}) if template["name"] == entry_point]
# Out:
# [{'name': 'main',
#   'inputs': {'parameters': [{'name': 'items',
#      'description': 'JSON array of STAC items to process'},
#     {'name': 'aoi',
#      'description': "Area of interest expressed as a bounding box 'minx,miny,maxx,maxy'"},
#     {'name': 'epsg',
#      'default': 'EPSG:4326',
#      'description': 'EPSG code of the bounding box coordinates'}]},
#   'outputs': {'parameters': [{'name': 'results',
#      'valueFrom': {'expression': "steps['argo-cwl'].outputs.parameters['results']"},
#      'description': 'JSON array results produced by the CWL execution'},
#     {'name': 'log',
#      'valueFrom': {'expression': "steps['argo-cwl'].outputs.parameters['log']"},
#      'description': 'Log produced by the CWL execution'},
#     {'name': 'usage-report',
#      'valueFrom': {'expression': "steps['argo-cwl'].outputs.parameters['usage-report']"},
#      'description': 'Usage report produced by the CWL execution'},
#     {'name': 'stac-catalog',
#      'valueFrom': {'expression': "steps['argo-cwl'].outputs.parameters['stac-catalog']"},
#      'description': 'STAC catalog with the detected water bodies and published on S3'},
#     {'name': 'feature-collection',
#      'valueFrom': {'expression': "steps['argo-cwl'].outputs.parameters['feature-collection']"},
#      'description': 'Feature collection with the detected water bodies'}],
#    'artifacts': [{'name': 'tool-logs',
#      'fromExpression': "steps['argo-cwl'].outputs.artifacts['tool-logs']"},
#     {'name': 'calrissian-output',
#      'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-output']"},
#     {'name': 'calrissian-stderr',
#      'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-stderr']"},
#     {'name': 'calrissian-report',
#      'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-report']"}]},
#   'metadata': {},
#   'steps': [[{'name': 'prepare',
#      'template': 'prepare',
#      'arguments': {'parameters': [{'name': 'items',
#         'value': '{{inputs.parameters.items}}'},
#        {'name': 'aoi', 'value': '{{inputs.parameters.aoi}}'},
#        {'name': 'epsg', 'value': '{{inputs.parameters.epsg}}'}]}}],
#    [{'name': 'validate-inputs',
#      'template': 'validate-inputs',
#      'arguments': {'parameters': [{'name': 'inputs',
#         'value': '{{steps.prepare.outputs.parameters.inputs}}'}]}}],
#    [{'name': 'argo-cwl',
#      'arguments': {'parameters': [{'name': 'entry_point',
#         'value': 'water-bodies'},
#        {'name': 'max_ram', 'value': '4G'},
#        {'name': 'max_cores', 'value': '4'},
#        {'name': 'parameters',
#         'value': '{{steps.prepare.outputs.parameters.inputs}}'},
#        {'name': 'cwl',
#         'value': '{{steps.prepare.outputs.parameters.workflow}}'}]},
#      'templateRef': {'name': 'argo-cwl-runner',
#       'template': 'calrissian-runner'}}]]}]

# %%
main = [template for template in response.json().get("spec", {}).get("templates", {}) if template["name"] == entry_point][0]

# %% [markdown]
# Get the "Process" inputs

# %%
for input_parameter in main["inputs"]["parameters"]:
    print(f"id: {input_parameter['name']}")
    print(f"description: {input_parameter.get('description', 'N/A')}")
    print(f"default value: {input_parameter.get('default', 'N/A')}")
    print("---")
# Out:
# id: items
# description: JSON array of STAC items to process
# default value: N/A
# ---
# id: aoi
# description: Area of interest expressed as a bounding box 'minx,miny,maxx,maxy'
# default value: N/A
# ---
# id: epsg
# description: EPSG code of the bounding box coordinates
# default value: EPSG:4326
# ---

# %% [markdown]
# Get the "Process" outputs

# %%
for output_parameter in main["outputs"]["parameters"]:
    print(f"id: {output_parameter['name']}")
    print(f"description: {output_parameter.get('description', 'N/A')}")
    print("---")
# Out:
# id: results
# description: JSON array results produced by the CWL execution
# ---
# id: log
# description: Log produced by the CWL execution
# ---
# id: usage-report
# description: Usage report produced by the CWL execution
# ---
# id: stac-catalog
# description: STAC catalog with the detected water bodies and published on S3
# ---
# id: feature-collection
# description: Feature collection with the detected water bodies
# ---

# %% [markdown]
# Get the "Process" artifacts

# %%
for artifact in main["outputs"]["artifacts"]:
    print(artifact)
    print(f"id: {artifact['name']}")
    print("---")
# Out:
# {'name': 'tool-logs', 'fromExpression': "steps['argo-cwl'].outputs.artifacts['tool-logs']"}
# id: tool-logs
# ---
# {'name': 'calrissian-output', 'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-output']"}
# id: calrissian-output
# ---
# {'name': 'calrissian-stderr', 'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-stderr']"}
# id: calrissian-stderr
# ---
# {'name': 'calrissian-report', 'fromExpression': "steps['argo-cwl'].outputs.artifacts['calrissian-report']"}
# id: calrissian-report
# ---

# %% [markdown]
# ## "Process" execution submission
#
# ```
# API endpoint: POST http://localhost:2746/api/v1/workflows/{namespace}/submit
# ```
#
# Payload
#
# ```json
# {
#   "resourceKind": "WorkflowTemplate",
#   "resourceName": "{name}",
#   "submitOptions": {
#     "parameters": ["key=value"]
#   }
# }
# ```

# %% [markdown]
# Create the payload

# %%
parameters = [{"items":["https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"]},
      {"aoi": "-121.399,39.834,-120.74,40.472"},
      {"epsg": "EPSG:4326"}]

# %% [markdown]
# Convert the parameters to a list of strings

# %%
payload_parameters = []
for param in parameters:
    for key, value in param.items():
        if isinstance(value, list):
            # Join the list items with double quotes and format with brackets
            items_str = '[' + ','.join(f'"{item}"' for item in value) + ']'
            payload_parameters.append(f"{key}={items_str}")
        else:
            payload_parameters.append(f"{key}={value}")

payload_parameters
# Out:
# ['items=["https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"]',
#  'aoi=-121.399,39.834,-120.74,40.472',
#  'epsg=EPSG:4326']

# %% [markdown]
# Execution payload:

# %%
# Payload with parameters
payload = {
  "resourceKind": "WorkflowTemplate",
  "resourceName": id,
  "submitOptions": {
    "parameters": payload_parameters
  }
}

payload
# Out:
# {'resourceKind': 'WorkflowTemplate',
#  'resourceName': 'water-bodies-detection',
#  'submitOptions': {'parameters': ['items=["https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20210708_0_L2A"]',
#    'aoi=-121.399,39.834,-120.74,40.472',
#    'epsg=EPSG:4326']}}

# %%
# Headers for API request
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
    "Content-Type": "application/json"
}

print(f"API endpoint: POST {ARGO_SERVER_URL}/workflows/{NAMESPACE}/submit")


# Submit the workflow and handle the response
response = requests.post(
    f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}/submit",
    headers=headers,
    json=payload,
    verify=False  # Use verify=True if you have valid SSL certificates
)

response.status_code
# Out:
# API endpoint: POST http://localhost:2746/api/v1/workflows/ns1/submit
# 200

# %%
if response.status_code == 200 or response.status_code == 201:
    # Decode JSON response
    workflow_info = response.json()
    workflow_name = workflow_info["metadata"]["name"]
    print(f"Workflow submitted successfully with name: {workflow_name}")
else:
    print("Failed to submit workflow:")
    print(response.text)
# Out:
# Workflow submitted successfully with name: water-bodies-detection-2hzc6

# %% [markdown]
# ## List "Jobs"
#
# ```
# API endpoint: GET http://localhost:2746/api/v1/workflows/{namespace}
# ```

# %%
print(f"API endpoint: GET {ARGO_SERVER_URL}/workflows/{NAMESPACE}")

response = requests.get(f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}", headers=headers)
# Out:
# API endpoint: GET http://localhost:2746/api/v1/workflows/ns1

# %%
for item in response.json().get("items", {}):
    print(f"name: {item.get('metadata', {}).get('name', {})}")
    print(f"submission date: {item.get('metadata', {}).get('creationTimestamp', {})}")
    print(f"uid: {item.get('metadata', {}).get('uid', {})}")
    print(f"submission date: {item.get('metadata', {}).get('creationTimestamp', {})}")
    print(f"job type: {item.get('spec', {}).get('workflowTemplateRef', {}).get('name', {})}") 
    print(f"status: {item.get('status', {}).get('phase', {})}")  
    print(f"started at: {item.get('status', {}).get('startedAt', {})}") 
    print(f"finished at: {item.get('status', {}).get('finishedAt', {})}")  
    print(f"progress: {item.get('status', {}).get('progress', {})}")      
    print("---")
# Out:
# name: water-bodies-detection-2hzc6
# submission date: 2024-11-07T21:09:20Z
# uid: 7f181f2a-112a-4584-96f8-3e6e4b8eacf5
# submission date: 2024-11-07T21:09:20Z
# job type: water-bodies-detection
# status: {}
# started at: None
# finished at: None
# progress: {}
# ---
# name: water-bodies-detection-9wwvw
# submission date: 2024-11-07T21:05:35Z
# uid: db48abcf-d614-4a74-99c1-26b3fde4d0d4
# submission date: 2024-11-07T21:05:35Z
# job type: water-bodies-detection
# status: Running
# started at: 2024-11-07T21:05:35Z
# finished at: None
# progress: 5/6
# ---
# name: water-bodies-detection-dcd2s
# submission date: 2024-11-07T21:02:10Z
# uid: 81277d16-258f-4431-91c5-b52e6129f7fb
# submission date: 2024-11-07T21:02:10Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T21:02:10Z
# finished at: 2024-11-07T21:04:02Z
# progress: 5/6
# ---
# name: water-bodies-detection-mc5rf
# submission date: 2024-11-07T18:40:52Z
# uid: 3bd56d8d-b8ac-47b7-bcf1-3cc597e569ee
# submission date: 2024-11-07T18:40:52Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T18:40:52Z
# finished at: 2024-11-07T18:43:14Z
# progress: 7/7
# ---
# name: water-bodies-detection-8cjrx
# submission date: 2024-11-07T15:27:39Z
# uid: 0f1b6be9-4aee-4901-93a0-d5da09ba08f6
# submission date: 2024-11-07T15:27:39Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T15:27:39Z
# finished at: 2024-11-07T15:29:47Z
# progress: 7/7
# ---
# name: water-bodies-detection-q8jf7
# submission date: 2024-11-07T14:47:47Z
# uid: 48154322-13b6-4e34-93d1-806dec95c7aa
# submission date: 2024-11-07T14:47:47Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T14:47:47Z
# finished at: 2024-11-07T14:51:39Z
# progress: 7/7
# ---
# name: water-bodies-detection-5fklk
# submission date: 2024-11-07T14:44:31Z
# uid: 9278a1a3-ef19-42b2-a6ba-c1b36f46a8ab
# submission date: 2024-11-07T14:44:31Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T14:44:31Z
# finished at: 2024-11-07T14:47:33Z
# progress: 3/4
# ---
# name: water-bodies-detection-b7r7h
# submission date: 2024-11-07T14:28:12Z
# uid: 9be6993e-0c95-4c05-b7d8-7b9a73769d2e
# submission date: 2024-11-07T14:28:12Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T14:28:12Z
# finished at: 2024-11-07T14:30:19Z
# progress: 7/7
# ---
# name: water-bodies-detection-vnxjv
# submission date: 2024-11-07T14:15:24Z
# uid: 63140888-051a-4375-a795-ebb81aa1d8ca
# submission date: 2024-11-07T14:15:24Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T14:15:24Z
# finished at: 2024-11-07T14:17:16Z
# progress: 5/6
# ---
# name: water-bodies-detection-v4ms2
# submission date: 2024-11-07T14:09:20Z
# uid: e88bdbbc-285f-424f-af10-e358f22d5a1f
# submission date: 2024-11-07T14:09:20Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T14:09:20Z
# finished at: 2024-11-07T14:11:32Z
# progress: 5/6
# ---
# name: water-bodies-detection-259hl
# submission date: 2024-11-07T13:18:06Z
# uid: 82029025-d768-4e4a-ab46-56437d7d7cce
# submission date: 2024-11-07T13:18:06Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T13:18:06Z
# finished at: 2024-11-07T13:20:07Z
# progress: 7/7
# ---
# name: water-bodies-detection-hz5dh
# submission date: 2024-11-07T13:13:23Z
# uid: b2bcfac3-b1d5-4087-aa0e-38274663e0a7
# submission date: 2024-11-07T13:13:23Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T13:13:23Z
# finished at: 2024-11-07T13:15:25Z
# progress: 7/7
# ---
# name: water-bodies-detection-kq8rn
# submission date: 2024-11-07T13:08:39Z
# uid: fb53c964-641d-4d04-bf08-9c0c8bb4ff2d
# submission date: 2024-11-07T13:08:39Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T13:08:39Z
# finished at: 2024-11-07T13:10:41Z
# progress: 7/7
# ---
# name: water-bodies-detection-st45m
# submission date: 2024-11-07T13:02:47Z
# uid: d96ad6e1-d50d-47fd-836f-b269a20f9900
# submission date: 2024-11-07T13:02:47Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T13:02:47Z
# finished at: 2024-11-07T13:04:43Z
# progress: 6/7
# ---
# name: water-bodies-detection-vmtvf
# submission date: 2024-11-07T12:55:12Z
# uid: b2ccb1f8-20e1-43dc-8f52-f5f591ab5e76
# submission date: 2024-11-07T12:55:12Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T12:55:12Z
# finished at: 2024-11-07T12:57:14Z
# progress: 6/7
# ---
# name: water-bodies-detection-gdm25
# submission date: 2024-11-07T12:37:23Z
# uid: 20f7f96b-88e8-43cb-8233-785a68011dc8
# submission date: 2024-11-07T12:37:23Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T12:37:23Z
# finished at: 2024-11-07T12:39:25Z
# progress: 6/7
# ---
# name: water-bodies-detection-hrvcq
# submission date: 2024-11-07T11:04:33Z
# uid: c2d6730e-4431-4b9a-aa85-f54adbc0dbe8
# submission date: 2024-11-07T11:04:33Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T11:04:33Z
# finished at: 2024-11-07T11:06:20Z
# progress: 6/7
# ---
# name: water-bodies-detection-vfntj
# submission date: 2024-11-07T10:46:32Z
# uid: 8446017b-f2a2-447e-ab1f-aaec0a3d8cb6
# submission date: 2024-11-07T10:46:32Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T10:46:32Z
# finished at: 2024-11-07T10:48:25Z
# progress: 6/7
# ---
# name: water-bodies-detection-wpptm
# submission date: 2024-11-07T08:01:58Z
# uid: 97e5af4a-1a82-455c-85cd-a8c1f7a010b0
# submission date: 2024-11-07T08:01:58Z
# job type: water-bodies-detection
# status: Failed
# started at: 2024-11-07T08:01:58Z
# finished at: 2024-11-07T08:03:50Z
# progress: 5/6
# ---
# name: water-bodies-detection-8dfrj
# submission date: 2024-11-07T06:17:59Z
# uid: 9ba225ad-0054-4269-928f-d5c14688f0f4
# submission date: 2024-11-07T06:17:59Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T06:17:59Z
# finished at: 2024-11-07T06:19:51Z
# progress: 6/6
# ---
# name: water-bodies-detection-bzfrz
# submission date: 2024-11-06T16:02:03Z
# uid: 8739eaf7-4883-4033-84cb-cab504f26b7f
# submission date: 2024-11-06T16:02:03Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T16:02:03Z
# finished at: 2024-11-06T16:05:20Z
# progress: 6/6
# ---
# name: water-bodies-detection-kwjqw
# submission date: 2024-11-06T15:58:21Z
# uid: 756a2e99-5930-451b-a846-0da6734931be
# submission date: 2024-11-06T15:58:21Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:58:21Z
# finished at: 2024-11-06T16:01:08Z
# progress: 6/6
# ---
# name: water-bodies-detection-52k25
# submission date: 2024-11-06T15:46:18Z
# uid: 923da8ea-60ef-48ef-87d5-6aae9e26accf
# submission date: 2024-11-06T15:46:18Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:53:30Z
# finished at: 2024-11-06T15:56:36Z
# progress: 6/6
# ---
# name: water-bodies-detection-z8s6d
# submission date: 2024-11-06T15:43:40Z
# uid: 991f791f-b24f-4e6f-b2da-02bb2bbab8c4
# submission date: 2024-11-06T15:43:40Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:48:40Z
# finished at: 2024-11-06T15:53:52Z
# progress: 6/6
# ---
# name: water-bodies-detection-7xrzm
# submission date: 2024-11-06T15:43:48Z
# uid: 83fc33d1-c845-4c9f-b991-7bd66aace2c2
# submission date: 2024-11-06T15:43:48Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:48:42Z
# finished at: 2024-11-06T15:53:48Z
# progress: 6/6
# ---
# name: water-bodies-detection-zn2cc
# submission date: 2024-11-06T15:43:21Z
# uid: 887e00a7-25c9-43a8-9611-468b18442039
# submission date: 2024-11-06T15:43:21Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:48:37Z
# finished at: 2024-11-06T15:53:29Z
# progress: 6/6
# ---
# name: water-bodies-detection-zk6v2
# submission date: 2024-11-06T15:36:34Z
# uid: cfd8b5c4-647a-4bd0-b559-89d3fd9deeb2
# submission date: 2024-11-06T15:36:34Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:36:34Z
# finished at: 2024-11-06T15:48:41Z
# progress: 6/6
# ---
# name: water-bodies-detection-kqbnz
# submission date: 2024-11-06T15:42:02Z
# uid: 0dfcf6b1-76c3-4f49-9f36-0c40dc663e18
# submission date: 2024-11-06T15:42:02Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:42:02Z
# finished at: 2024-11-06T15:48:39Z
# progress: 6/6
# ---
# name: water-bodies-detection-p5bzq
# submission date: 2024-11-06T15:37:30Z
# uid: 0bc2ac3a-2e0c-41a8-8041-63cd93e37e3d
# submission date: 2024-11-06T15:37:30Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-06T15:37:30Z
# finished at: 2024-11-06T15:48:36Z
# progress: 6/6
# ---

# %% [markdown]
# The element `status.nodes` provides detailed information about the workflow nodes

# %%
job_name = workflow_info.get("metadata", {}).get("name", {}) 

job_name
# Out:
# 'water-bodies-detection-2hzc6'

# %% [markdown]
# ## "Job" monitoring
#
# ```
# API endpoint: GET http://localhost:2746/api/v1/workflows/{namespace}/{name}
# ```

# %%
print(f"API endpoint: GET {ARGO_SERVER_URL}/workflows/{NAMESPACE}/{workflow_name}")

# Headers for API request
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
    "Content-Type": "application/json"
}

def get_workflow_status(workflow_name):
    """Fetches the current status of the workflow."""
    response = requests.get(
        f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}/{workflow_name}",
        headers=headers,
        verify=False  # Use verify=True with valid SSL certificates
    )

    if response.status_code == 200:
        workflow_info = response.json()
        status = workflow_info.get("status", {}).get("phase", "Unknown")
        return status, workflow_info
    else:
        print(f"Failed to retrieve workflow status: {response.status_code}")
        return None

# Monitor the workflow status until it reaches a terminal state
while True:
    status, workflow_status = get_workflow_status(job_name)
    
    if status:
        print(f"Workflow Status: {status}")

        # Check if the workflow has completed
        if status in ["Succeeded", "Failed", "Error"]:
            print(f"Workflow has completed with status: {status}")
            break
    else:
        print("Unable to retrieve workflow status. Exiting monitoring.")
        break

    # Wait for 10 seconds before the next check
    time.sleep(10)
# Out:
# API endpoint: GET http://localhost:2746/api/v1/workflows/ns1/water-bodies-detection-2hzc6
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Running
# Workflow Status: Succeeded
# Workflow has completed with status: Succeeded

# %%
print(f"name: {workflow_status.get('metadata', {}).get('name', {})}")
print(f"submission date: {workflow_status.get('metadata', {}).get('creationTimestamp', {})}")
print(f"uid: {workflow_status.get('metadata', {}).get('uid', {})}")
print(f"submission date: {workflow_status.get('metadata', {}).get('creationTimestamp', {})}")
print(f"job type: {workflow_status.get('spec', {}).get('workflowTemplateRef', {}).get('name', {})}") 
print(f"status: {workflow_status.get('status', {}).get('phase', {})}")  
print(f"started at: {workflow_status.get('status', {}).get('startedAt', {})}") 
print(f"finished at: {workflow_status.get('status', {}).get('finishedAt', {})}")  
print(f"progress: {workflow_status.get('status', {}).get('progress', {})}")      
print("---")
# Out:
# name: water-bodies-detection-2hzc6
# submission date: 2024-11-07T21:09:20Z
# uid: 7f181f2a-112a-4584-96f8-3e6e4b8eacf5
# submission date: 2024-11-07T21:09:20Z
# job type: water-bodies-detection
# status: Succeeded
# started at: 2024-11-07T21:09:20Z
# finished at: 2024-11-07T21:11:21Z
# progress: 7/7
# ---

# %% [markdown]
# ## Get the "job" outputs: parameters and artifacts

# %% [markdown]
# List the "job" outputs parameters

# %%
for output_parameter in workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("parameters"):
    print(f"id: {output_parameter['name']}")
    print(f"description: {output_parameter.get('description', 'N/A')}")
    print(f"value: {output_parameter.get('value', 'N/A')}")
    print("---")
# Out:
# id: results
# description: JSON array results produced by the CWL execution
# value: {
#     "stac_catalog": {
#         "location": "file:///calrissian/results/34u7ot1c",
#         "basename": "34u7ot1c",
#         "class": "Directory",
#         "listing": [
#             {
#                 "class": "File",
#                 "location": "file:///calrissian/results/34u7ot1c/catalog.json",
#                 "basename": "catalog.json",
#                 "checksum": "sha1$f1994683c2e2b8d21aab7f0c0c05b76b850ac21e",
#                 "size": 359,
#                 "path": "/calrissian/results/34u7ot1c/catalog.json"
#             },
#             {
#                 "class": "Directory",
#                 "location": "file:///calrissian/results/34u7ot1c/S2A_10TFK_20210708_0_L2A",
#                 "basename": "S2A_10TFK_20210708_0_L2A",
#                 "listing": [
#                     {
#                         "class": "File",
#                         "location": "file:///calrissian/results/34u7ot1c/S2A_10TFK_20210708_0_L2A/S2A_10TFK_20210708_0_L2A.json",
#                         "basename": "S2A_10TFK_20210708_0_L2A.json",
#                         "checksum": "sha1$25ed3289eca3b8c983ab9656870a8c26601df580",
#                         "size": 3444,
#                         "path": "/calrissian/results/34u7ot1c/S2A_10TFK_20210708_0_L2A/S2A_10TFK_20210708_0_L2A.json"
#                     },
#                     {
#                         "class": "File",
#                         "location": "file:///calrissian/results/34u7ot1c/S2A_10TFK_20210708_0_L2A/otsu.tif",
#                         "basename": "otsu.tif",
#                         "checksum": "sha1$210598cf619d49eabfdc24414bd445f59668f3bd",
#                         "size": 289288,
#                         "path": "/calrissian/results/34u7ot1c/S2A_10TFK_20210708_0_L2A/otsu.tif"
#                     }
#                 ],
#                 "path": "/calrissian/results/34u7ot1c/S2A_10TFK_20210708_0_L2A"
#             }
#         ],
#         "path": "/calrissian/results/34u7ot1c"
#     }
# }
# ---
# id: log
# description: Log produced by the CWL execution
# value: INFO calrissian 0.16.0 (cwltool 3.1.20231114134824)
# INFO Resolved '/calrissian/cwl.json#water-bodies' to 'file:///calrissian/cwl.json#water-bodies'
# INFO [workflow ] starting step node_water_bodies
# INFO [step node_water_bodies] start
# INFO [workflow node_water_bodies] starting step node_crop
# INFO [step node_crop] start
# INFO [step node_crop] start
# INFO [workflow ] start
# INFO [workflow node_water_bodies] start
# INFO [step node_crop] completed success
# INFO [workflow node_water_bodies] starting step node_normalized_difference
# INFO [step node_normalized_difference] start
# INFO [step node_normalized_difference] completed success
# INFO [workflow node_water_bodies] starting step node_otsu
# INFO [step node_otsu] start
# INFO [step node_otsu] completed success
# INFO [workflow node_water_bodies] completed success
# INFO [step node_water_bodies] completed success
# INFO [workflow ] starting step node_stac
# INFO [step node_stac] start
# INFO [step node_stac] completed success
# INFO [workflow ] completed success
# INFO Final process status is success
# ---
# id: usage-report
# description: Usage report produced by the CWL execution
# value: {
#     "cores_allowed": 4.0,
#     "ram_mb_allowed": 4000.0,
#     "children": [
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 100.761236,
#             "exit_code": 0,
#             "name": "node_crop_2",
#             "start_time": "2024-11-07T21:09:55+00:00",
#             "finish_time": "2024-11-07T21:10:29+00:00",
#             "elapsed_hours": 0.009444444444444445,
#             "elapsed_seconds": 34.0,
#             "ram_megabyte_hours": 5.070447502222222,
#             "cpu_hours": 0.009444444444444445
#         },
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 87.602514,
#             "exit_code": 0,
#             "name": "node_crop",
#             "start_time": "2024-11-07T21:09:55+00:00",
#             "finish_time": "2024-11-07T21:10:31+00:00",
#             "elapsed_hours": 0.01,
#             "elapsed_seconds": 36.0,
#             "ram_megabyte_hours": 5.36870912,
#             "cpu_hours": 0.01
#         },
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 224.221619,
#             "exit_code": 0,
#             "name": "node_normalized_difference",
#             "start_time": "2024-11-07T21:10:32+00:00",
#             "finish_time": "2024-11-07T21:10:39+00:00",
#             "elapsed_hours": 0.0019444444444444444,
#             "elapsed_seconds": 7.0,
#             "ram_megabyte_hours": 1.043915662222222,
#             "cpu_hours": 0.0019444444444444444
#         },
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 0.289288,
#             "exit_code": 0,
#             "name": "node_otsu",
#             "start_time": "2024-11-07T21:10:41+00:00",
#             "finish_time": "2024-11-07T21:10:43+00:00",
#             "elapsed_hours": 0.0005555555555555556,
#             "elapsed_seconds": 2.0,
#             "ram_megabyte_hours": 0.29826161777777777,
#             "cpu_hours": 0.0005555555555555556
#         },
#         {
#             "cpus": 1.0,
#             "ram_megabytes": 536.870912,
#             "disk_megabytes": 0.0,
#             "exit_code": 0,
#             "name": "node_stac",
#             "start_time": "2024-11-07T21:10:45+00:00",
#             "finish_time": "2024-11-07T21:10:46+00:00",
#             "elapsed_hours": 0.0002777777777777778,
#             "elapsed_seconds": 1.0,
#             "ram_megabyte_hours": 0.14913080888888888,
#             "cpu_hours": 0.0002777777777777778
#         }
#     ],
#     "start_time": "2024-11-07T21:09:55+00:00",
#     "finish_time": "2024-11-07T21:10:46+00:00",
#     "elapsed_hours": 0.014166666666666666,
#     "elapsed_seconds": 51.0,
#     "total_cpu_hours": 0.02222222222222222,
#     "total_ram_megabyte_hours": 11.93046471111111,
#     "total_disk_megabytes": 412.874657,
#     "total_tasks": 5,
#     "max_parallel_cpus": 2.0,
#     "max_parallel_ram_megabytes": 1073.741824,
#     "max_parallel_tasks": 2
# }
# ---
# id: stac-catalog
# description: STAC catalog with the detected water bodies and published on S3
# value: s3://results/water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5/catalog.json
# ---
# id: feature-collection
# description: Feature collection with the detected water bodies
# value: {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "stac_version": "1.0.0",
#       "stac_extensions": [
#         "https://stac-extensions.github.io/projection/v1.1.0/schema.json",
#         "https://stac-extensions.github.io/raster/v1.1.0/schema.json"
#       ],
#       "id": "S2A_10TFK_20210708_0_L2A",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -121.39905410179915,
#               39.833916743259095
#             ],
#             [
#               -120.76135965075635,
#               39.82336095080461
#             ],
#             [
#               -120.73995321724426,
#               40.471999341669175
#             ],
#             [
#               -121.38373773482932,
#               40.482798837728375
#             ],
#             [
#               -121.39905410179915,
#               39.833916743259095
#             ]
#           ]
#         ]
#       },
#       "bbox": [
#         -121.39905410179915,
#         39.82336095080461,
#         -120.73995321724426,
#         40.482798837728375
#       ],
#       "properties": {
#         "proj:epsg": null,
#         "proj:geometry": {
#           "type": "Polygon",
#           "coordinates": [
#             [
#               [
#                 636990.0,
#                 4410550.0
#               ],
#               [
#                 691590.0,
#                 4410550.0
#               ],
#               [
#                 691590.0,
#                 4482600.0
#               ],
#               [
#                 636990.0,
#                 4482600.0
#               ],
#               [
#                 636990.0,
#                 4410550.0
#               ]
#             ]
#           ]
#         },
#         "proj:bbox": [
#           636990.0,
#           4410550.0,
#           691590.0,
#           4482600.0
#         ],
#         "proj:shape": [
#           7205,
#           5460
#         ],
#         "proj:transform": [
#           10.0,
#           0.0,
#           636990.0,
#           0.0,
#           -10.0,
#           4482600.0,
#           0.0,
#           0.0,
#           1.0
#         ],
#         "proj:wkt2": "PROJCS[\"WGS 84 / UTM zone 10N\",GEOGCS[\"WGS 84\",DATUM[\"WGS_1984\",SPHEROID[\"WGS 84\",6378137,298.257223563,AUTHORITY[\"EPSG\",\"7030\"]],AUTHORITY[\"EPSG\",\"6326\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4326\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",-123],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",500000],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH],AUTHORITY[\"EPSG\",\"32610\"]]",
#         "datetime": "2021-07-08T19:03:25Z"
#       },
#       "links": [
#         {
#           "rel": "collection",
#           "href": "s3://results/water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5/water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5/collection.json",
#           "type": "application/json",
#           "title": "Processing results"
#         },
#         {
#           "rel": "root",
#           "href": "s3://results/water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5/catalog.json",
#           "type": "application/json"
#         },
#         {
#           "rel": "self",
#           "href": "s3://results/water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5/water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5/S2A_10TFK_20210708_0_L2A/S2A_10TFK_20210708_0_L2A.json",
#           "type": "application/json"
#         },
#         {
#           "rel": "parent",
#           "href": "s3://results/water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5/water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5/collection.json",
#           "type": "application/json",
#           "title": "Processing results"
#         }
#       ],
#       "assets": {
#         "data": {
#           "href": "s3://results//tmp/catalog/S2A_10TFK_20210708_0_L2A/otsu.tif",
#           "type": "image/tiff; application=geotiff",
#           "raster:bands": [
#             {
#               "data_type": "uint8",
#               "scale": 1.0,
#               "offset": 0.0,
#               "sampling": "area",
#               "nodata": 0.0
#             }
#           ],
#           "roles": [
#             "data",
#             "visual"
#           ]
#         }
#       },
#       "collection": "water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5"
#     }
#   ]
# }
# ---

# %% [markdown]
# List the "job" outputs artifacts

# %%
for artifact in workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("artifacts"):
    print(f"id: {artifact['name']}")
    print(f"location in artifact bucket: {artifact.get('s3').get('key')}")
    print("---")
# Out:
# id: tool-logs
# location in artifact bucket: water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5-artifacts/tool-logs.tgz
# ---
# id: calrissian-output
# location in artifact bucket: water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5-artifacts/calrissian-output.tgz
# ---
# id: calrissian-stderr
# location in artifact bucket: water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5-artifacts/calrissian-stderr.tgz
# ---
# id: calrissian-report
# location in artifact bucket: water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5-artifacts/calrissian-report.tgz
# ---

# %%
workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("artifacts")
# Out:
# [{'name': 'tool-logs',
#   'path': '/calrissian/logs',
#   's3': {'key': 'water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5-artifacts/tool-logs.tgz'}},
#  {'name': 'calrissian-output',
#   'path': '/tmp/calrissian-output.json',
#   's3': {'key': 'water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5-artifacts/calrissian-output.tgz'}},
#  {'name': 'calrissian-stderr',
#   'path': '/tmp/calrissian-stderr.txt',
#   's3': {'key': 'water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5-artifacts/calrissian-stderr.tgz'}},
#  {'name': 'calrissian-report',
#   'path': '/tmp/calrissian-report.json',
#   's3': {'key': 'water-bodies-detection-2hzc6-7f181f2a-112a-4584-96f8-3e6e4b8eacf5-artifacts/calrissian-report.tgz'}}]

# %% [markdown]
# ## Download the "job" artifacts

# %%
[artifact.get("name") for artifact in workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("artifacts")]
# Out:
# ['tool-logs', 'calrissian-output', 'calrissian-stderr', 'calrissian-report']

# %%
# Configuration

id_discriminator = "workflows"
id = job_name
node_id = job_name
ARTIFACT_BASE_URL = f"http://localhost:2746/artifact-files/{NAMESPACE}/{id_discriminator}/{id}/{node_id}/outputs" #/tool-logs"


# Headers for authentication
headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}"
}

# Download the artifacts
for artifact in workflow_status.get("status").get("nodes").get(job_name).get("outputs").get("artifacts"):
    
    print(f"API endpoint: GET {ARTIFACT_BASE_URL}/{artifact.get('name')}")
    response = requests.get(f"{ARTIFACT_BASE_URL}/{artifact.get('name')}", headers=headers, stream=True)

    output_file = f"{artifact.get('name')}.tar.gz"  
    if response.status_code == 200:
        with open(output_file, "wb") as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
        print(f"Artifact downloaded successfully and saved as {output_file}")
    else:
        print(f"Failed to download artifact. Status code: {response.status_code}")
        print(response.text)
# Out:
# API endpoint: GET http://localhost:2746/artifact-files/ns1/workflows/water-bodies-detection-2hzc6/water-bodies-detection-2hzc6/outputs/tool-logs
# Artifact downloaded successfully and saved as tool-logs.tar.gz
# API endpoint: GET http://localhost:2746/artifact-files/ns1/workflows/water-bodies-detection-2hzc6/water-bodies-detection-2hzc6/outputs/calrissian-output
# Artifact downloaded successfully and saved as calrissian-output.tar.gz
# API endpoint: GET http://localhost:2746/artifact-files/ns1/workflows/water-bodies-detection-2hzc6/water-bodies-detection-2hzc6/outputs/calrissian-stderr
# Artifact downloaded successfully and saved as calrissian-stderr.tar.gz
# API endpoint: GET http://localhost:2746/artifact-files/ns1/workflows/water-bodies-detection-2hzc6/water-bodies-detection-2hzc6/outputs/calrissian-report
# Artifact downloaded successfully and saved as calrissian-report.tar.gz

# %% [markdown]
# ## Delete "Job"

# %%
print(f"API endpoint: DELETE {ARGO_SERVER_URL}/workflows/{NAMESPACE}/{job_name}S")

# response = requests.delete(f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}/{job_name}", headers=headers)

print(response.status_code)
# Out:
# API endpoint: DELETE http://localhost:2746/api/v1/workflows/ns1/water-bodies-detection-2hzc6S
# 200

# %% [markdown]
# Check the "job" no longer exists:

# %%
response = requests.get(f"{ARGO_SERVER_URL}/workflows/{NAMESPACE}/{job_name}", headers=headers)

response.status_code
# Out:
# 200
